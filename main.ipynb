# %%
import re
import os

with open('sentences.csv', 'w', encoding='utf-8') as file: 
    row = '%s\t%s\t%s\t%s\t%s\t%s\t%s\n'
    file.write(row % ('Path', 'Tag', 'Full sentence', 'Tagged mistake', 
                   'Corrected mistake', 'Correct/incorrect', 'Group'))
path = './data/exam2017_1'
for root, dirs, files in os.walk(path):
    for file in files:
        if ".ann" in file:
            #print(root, dirs, file)
            final = os.path.join(root, file)
            with open(filepath, encoding="utf-8") as file:
                annot_txt = file.read()
            print(annot_txt)
# Out:
# T1	Superlative_adj 16 30	the most great
# #1	AnnotatorNotes T1	greatest
# T2	Defining 49 54	, who
# T3	lex_item_choice 63 82	entertainment items
# #2	AnnotatorNotes T3	entertaining content
# T4	Spelling 111 121	prospecity
# #3	AnnotatorNotes T4	prosperity
# T5	Articles 107 121	the prospecity
# #4	AnnotatorNotes T5	prosperity
# T6	Absence_comp_colloc 174 179	views
# #5	AnnotatorNotes T6	points of view
# T7	Prepositions 216 233	From the one hand
# #6	AnnotatorNotes T7	On the one hand
# T8	Category_confusion 356 364	relaxing
# #7	AnnotatorNotes T8	relaxation
# T9	Articles 412 419	a right
# #8	AnnotatorNotes T9	right
# T10	Punctuation 446 449	and
# #9	AnnotatorNotes T10	, and
# T11	lex_item_choice 529 538	enjoyment
# #10	AnnotatorNotes T11	actions
# T12	Articles 553 591	the copying and sharing music or films
# #11	AnnotatorNotes T12	copying and sharing music or films
# T13	Articles 595 615	of non-original form
# #12	AnnotatorNotes T13	a non-original form
# T14	Category_confusion 624 637	deteriorating
# #13	AnnotatorNotes T14	deterioration
# T15	Prepositions 675 677	of
# #14	AnnotatorNotes T15	for
# T16	Articles 758 770	the concerts
# #15	AnnotatorNotes T16	concerts
# T17	Absence_explanation 681 687	can be
# #16	AnnotatorNotes T17	can be in the accessibility of
# T18	Punctuation 744 745	,
# T19	Redundant_comp 812 821	producing
# A1	Delete T19
# T20	lex_item_choice 822 828	really
# #17	AnnotatorNotes T20	just
# T21	Category_confusion 847 856	to create
# #18	AnnotatorNotes T21	creating
# T22	lex_item_choice 1167 1174	decided
# #19	AnnotatorNotes T22	solved
# T23	Tense_choice 1164 1174	is decided
# #20	AnnotatorNotes T23	was solved
# T24	Often_confused 1196 1201	which
# #21	AnnotatorNotes T24	that
# T25	Absence_explanation 1228 1232	free
# #22	AnnotatorNotes T25	that can be used for free
# T26	Articles 1345 1352	a right
# #23	AnnotatorNotes T26	right
# T27	Absence_explanation 1360 1368	a wealth
# #24	AnnotatorNotes T27	cultural wealth
# T28	Articles 1360 1368	a wealth
# #25	AnnotatorNotes T28	cultural wealth
# T29	Articles 1127 1140	a free wealth
# #26	AnnotatorNotes T29	free cultural wealth
# T30	Absence_explanation 1127 1140	a free wealth
# #27	AnnotatorNotes T30	free cultural wealth
# T31	Absence_explanation 1396 1405	to public
# #28	AnnotatorNotes T31	for public to enjoy it
# T32	Prepositions 1504 1525	listening for a music
# #29	AnnotatorNotes T32	listening to music
# T33	Articles 1518 1525	a music
# #30	AnnotatorNotes T33	music
# T34	Articles 1661 1671	equal form
# #31	AnnotatorNotes T34	an equal form
# T35	note 1671 1672	.
# #32	AnnotatorNotes T35	ABl
# T36	ADV 0 8	Nowadays
# #33	AnnotatorNotes T36	lemma = 'nowadays'
# T37	NUM 9 12	one
# #34	AnnotatorNotes T37	lemma = 'one'
# T38	ADP 13 15	of
# #35	AnnotatorNotes T38	lemma = 'of'
# T39	DET 16 19	the
# #36	AnnotatorNotes T39	lemma = 'the'
# T40	ADV 20 24	most
# #37	AnnotatorNotes T40	lemma = 'most'
# T41	ADJ 25 30	great
# #38	AnnotatorNotes T41	lemma = 'great'
# T42	NOUN 31 39	problems
# #39	AnnotatorNotes T42	lemma = 'problem'
# T43	ADP 40 43	for
# #40	AnnotatorNotes T43	lemma = 'for'
# T44	PRON 44 49	those
# #41	AnnotatorNotes T44	lemma = 'that'
# T45	PUNCT 49 50	,
# #42	AnnotatorNotes T45	lemma = ','
# T46	PRON 51 54	who
# #43	AnnotatorNotes T46	lemma = 'who'
# T47	VERB 55 62	produce
# #44	AnnotatorNotes T47	lemma = 'produce'
# T48	ADJ 63 76	entertainment
# #45	AnnotatorNotes T48	lemma = 'entertainment'
# T49	NOUN 77 82	items
# #46	AnnotatorNotes T49	lemma = 'item'
# T50	ADP 83 87	like
# #47	AnnotatorNotes T50	lemma = 'like'
# T51	NOUN 88 93	music
# #48	AnnotatorNotes T51	lemma = 'music'
# T52	CCONJ 94 97	and
# #49	AnnotatorNotes T52	lemma = 'and'
# T53	NOUN 98 103	films
# #50	AnnotatorNotes T53	lemma = 'film'
# T54	AUX 104 106	is
# #51	AnnotatorNotes T54	lemma = 'be'
# T55	DET 107 110	the
# #52	AnnotatorNotes T55	lemma = 'the'
# T56	NOUN 111 121	prospecity
# #53	AnnotatorNotes T56	lemma = 'prospecity'
# T57	ADP 122 124	of
# #54	AnnotatorNotes T57	lemma = 'of'
# T58	ADJ 125 131	pirate
# #55	AnnotatorNotes T58	lemma = 'pirate'
# T59	NOUN 132 138	copies
# #56	AnnotatorNotes T59	lemma = 'copy'
# T60	ADP 139 141	of
# #57	AnnotatorNotes T60	lemma = 'of'
# T61	DET 142 147	their
# #58	AnnotatorNotes T61	lemma = 'their'
# T62	NOUN 148 156	products
# #59	AnnotatorNotes T62	lemma = 'product'
# T63	PUNCT 156 157	.
# #60	AnnotatorNotes T63	lemma = '.'
# T64	ADV 158 160	So
# #61	AnnotatorNotes T64	lemma = 'so'
# T65	PUNCT 160 161	,
# #62	AnnotatorNotes T65	lemma = ','
# T66	ADV 162 167	there
# #63	AnnotatorNotes T66	lemma = 'there'
# T67	VERB 168 171	are
# #64	AnnotatorNotes T67	lemma = 'be'
# T68	NUM 172 173	2
# #65	AnnotatorNotes T68	lemma = '2'
# T69	NOUN 174 179	views
# #66	AnnotatorNotes T69	lemma = 'view'
# T70	ADP 180 182	on
# #67	AnnotatorNotes T70	lemma = 'on'
# T71	DET 183 186	the
# #68	AnnotatorNotes T71	lemma = 'the'
# T72	NOUN 187 196	existence
# #69	AnnotatorNotes T72	lemma = 'existence'
# T73	ADP 197 199	of
# #70	AnnotatorNotes T73	lemma = 'of'
# T74	DET 200 204	such
# #71	AnnotatorNotes T74	lemma = 'such'
# T75	NOUN 205 214	phenomena
# #72	AnnotatorNotes T75	lemma = 'phenomena'
# T76	PUNCT 214 215	.
# #73	AnnotatorNotes T76	lemma = '.'
# T77	ADP 216 220	From
# #74	AnnotatorNotes T77	lemma = 'from'
# T78	DET 221 224	the
# #75	AnnotatorNotes T78	lemma = 'the'
# T79	NUM 225 228	one
# #76	AnnotatorNotes T79	lemma = 'one'
# T80	NOUN 229 233	hand
# #77	AnnotatorNotes T80	lemma = 'hand'
# T81	PUNCT 233 234	,
# #78	AnnotatorNotes T81	lemma = ','
# T82	PRON 235 243	everyone
# #79	AnnotatorNotes T82	lemma = 'everyone'
# T83	AUX 244 250	should
# #80	AnnotatorNotes T83	lemma = 'shall'
# T84	VERB 251 258	respect
# #81	AnnotatorNotes T84	lemma = 'respect'
# T85	DET 259 263	such
# #82	AnnotatorNotes T85	lemma = 'such'
# T86	ADJ 264 272	talented
# #83	AnnotatorNotes T86	lemma = 'talent'
# T87	NOUN 273 279	people
# #84	AnnotatorNotes T87	lemma = 'people'
# T88	ADP 280 282	as
# #85	AnnotatorNotes T88	lemma = 'as'
# T89	NOUN 283 292	musicians
# #86	AnnotatorNotes T89	lemma = 'musician'
# T90	CCONJ 293 296	and
# #87	AnnotatorNotes T90	lemma = 'and'
# T91	NOUN 297 306	producers
# #88	AnnotatorNotes T91	lemma = 'producer'
# T92	PRON 307 310	who
# #89	AnnotatorNotes T92	lemma = 'who'
# T93	VERB 311 318	provide
# #90	AnnotatorNotes T93	lemma = 'provide'
# T94	PRON 319 321	us
# #91	AnnotatorNotes T94	lemma = 'us'
# T95	ADP 322 326	with
# #92	AnnotatorNotes T95	lemma = 'with'
# T96	ADV 327 333	really
# #93	AnnotatorNotes T96	lemma = 'really'
# T97	ADJ 334 340	useful
# #94	AnnotatorNotes T97	lemma = 'useful'
# T98	NOUN 341 347	things
# #95	AnnotatorNotes T98	lemma = 'thing'
# T99	ADP 348 351	for
# #96	AnnotatorNotes T99	lemma = 'for'
# T100	DET 352 355	our
# #97	AnnotatorNotes T100	lemma = 'us'
# T101	NOUN 356 364	relaxing
# #98	AnnotatorNotes T101	lemma = 'relaxing'
# T102	CCONJ 365 367	or
# #99	AnnotatorNotes T102	lemma = 'or'
# T103	ADJ 368 378	scientific
# #100	AnnotatorNotes T103	lemma = 'scientific'
# T104	NOUN 379 389	satisfying
# #101	AnnotatorNotes T104	lemma = 'satisfy'
# T105	PUNCT 389 390	.
# #102	AnnotatorNotes T105	lemma = '.'
# T106	ADV 391 395	Thus
# #103	AnnotatorNotes T106	lemma = 'thus'
# T107	PUNCT 395 396	,
# #104	AnnotatorNotes T107	lemma = ','
# T108	PRON 397 401	they
# #105	AnnotatorNotes T108	lemma = 'they'
# T109	AUX 402 406	must
# #106	AnnotatorNotes T109	lemma = 'must'
# T110	VERB 407 411	have
# #107	AnnotatorNotes T110	lemma = 'have'
# T111	DET 412 413	a
# #108	AnnotatorNotes T111	lemma = 'a'
# T112	NOUN 414 419	right
# #109	AnnotatorNotes T112	lemma = 'right'
# T113	PART 420 422	to
# #110	AnnotatorNotes T113	lemma = 'to'
# T114	AUX 423 425	be
# #111	AnnotatorNotes T114	lemma = 'be'
# T115	VERB 426 430	paid
# #112	AnnotatorNotes T115	lemma = 'pay'
# T116	ADP 431 434	for
# #113	AnnotatorNotes T116	lemma = 'for'
# T117	DET 435 440	their
# #114	AnnotatorNotes T117	lemma = 'their'
# T118	NOUN 441 445	work
# #115	AnnotatorNotes T118	lemma = 'work'
# T119	CCONJ 446 449	and
# #116	AnnotatorNotes T119	lemma = 'and'
# T120	NOUN 450 455	users
# #117	AnnotatorNotes T120	lemma = 'user'
# T121	ADP 456 458	of
# #118	AnnotatorNotes T121	lemma = 'of'
# T122	DET 459 462	the
# #119	AnnotatorNotes T122	lemma = 'the'
# T123	NOUN 463 471	Internet
# #120	AnnotatorNotes T123	lemma = 'internet'
# T124	PRON 472 475	who
# #121	AnnotatorNotes T124	lemma = 'who'
# T125	VERB 476 484	download
# #122	AnnotatorNotes T125	lemma = 'download'
# T126	NOUN 485 491	pirate
# #123	AnnotatorNotes T126	lemma = 'pirate'
# T127	NOUN 492 497	files
# #124	AnnotatorNotes T127	lemma = 'file'
# T128	AUX 498 504	should
# #125	AnnotatorNotes T128	lemma = 'shall'
# T129	AUX 505 507	be
# #126	AnnotatorNotes T129	lemma = 'be'
# T130	VERB 508 516	punished
# #127	AnnotatorNotes T130	lemma = 'punish'
# T131	ADP 517 520	for
# #128	AnnotatorNotes T131	lemma = 'for'
# T132	ADJ 521 528	illegal
# #129	AnnotatorNotes T132	lemma = 'illegal'
# T133	NOUN 529 538	enjoyment
# #130	AnnotatorNotes T133	lemma = 'enjoyment'
# T134	PUNCT 538 539	.
# #131	AnnotatorNotes T134	lemma = '.'
# T135	ADV 540 551	Furthermore
# #132	AnnotatorNotes T135	lemma = 'furthermore'
# T136	PUNCT 551 552	,
# #133	AnnotatorNotes T136	lemma = ','
# T137	DET 553 556	the
# #134	AnnotatorNotes T137	lemma = 'the'
# T138	VERB 557 564	copying
# #135	AnnotatorNotes T138	lemma = 'copy'
# T139	CCONJ 565 568	and
# #136	AnnotatorNotes T139	lemma = 'and'
# T140	VERB 569 576	sharing
# #137	AnnotatorNotes T140	lemma = 'shar'
# T141	NOUN 577 582	music
# #138	AnnotatorNotes T141	lemma = 'music'
# T142	CCONJ 583 585	or
# #139	AnnotatorNotes T142	lemma = 'or'
# T143	NOUN 586 591	films
# #140	AnnotatorNotes T143	lemma = 'film'
# T144	ADP 592 594	in
# #141	AnnotatorNotes T144	lemma = 'in'
# T145	ADP 595 597	of
# #142	AnnotatorNotes T145	lemma = 'of'
# T146	ADV 598 601	non
# #143	AnnotatorNotes T146	lemma = 'non'
# T147	PUNCT 601 602	-
# #144	AnnotatorNotes T147	lemma = '-'
# T148	ADJ 602 610	original
# #145	AnnotatorNotes T148	lemma = 'original'
# T149	NOUN 611 615	form
# #146	AnnotatorNotes T149	lemma = 'form'
# T150	NOUN 616 620	lead
# #147	AnnotatorNotes T150	lemma = 'lead'
# T151	ADP 621 623	to
# #148	AnnotatorNotes T151	lemma = 'to'
# T152	NOUN 624 637	deteriorating
# #149	AnnotatorNotes T152	lemma = 'deteriorate'
# T153	ADP 638 640	of
# #150	AnnotatorNotes T153	lemma = 'of'
# T154	DET 641 644	the
# #151	AnnotatorNotes T154	lemma = 'the'
# T155	NOUN 645 653	products
# #152	AnnotatorNotes T155	lemma = 'product'
# T156	ADP 653 654	’
# #153	AnnotatorNotes T156	lemma = '''
# T157	NOUN 655 662	quality
# #154	AnnotatorNotes T157	lemma = 'quality'
# T158	PUNCT 662 663	.
# #155	AnnotatorNotes T158	lemma = '.'
# T159	DET 664 667	The
# #156	AnnotatorNotes T159	lemma = 'the'
# T160	NOUN 668 674	reason
# #157	AnnotatorNotes T160	lemma = 'reason'
# T161	ADP 675 677	of
# #158	AnnotatorNotes T161	lemma = 'of'
# T162	PRON 678 680	it
# #159	AnnotatorNotes T162	lemma = 'it'
# T163	AUX 681 684	can
# #160	AnnotatorNotes T163	lemma = 'can'
# T164	AUX 685 687	be
# #161	AnnotatorNotes T164	lemma = 'be'
# T165	ADV 688 693	films
# #162	AnnotatorNotes T165	lemma = 'film'
# T166	VERB 694 702	recorded
# #163	AnnotatorNotes T166	lemma = 'record'
# T167	ADP 703 705	on
# #164	AnnotatorNotes T167	lemma = 'on'
# T168	NOUN 706 718	videocameras
# #165	AnnotatorNotes T168	lemma = 'videocamera'
# T169	ADP 719 723	from
# #166	AnnotatorNotes T169	lemma = 'from'
# T170	NOUN 724 735	cinemaparks
# #167	AnnotatorNotes T170	lemma = 'cinemapark'
# T171	CCONJ 736 738	or
# #168	AnnotatorNotes T171	lemma = 'or'
# T172	NOUN 739 744	music
# #169	AnnotatorNotes T172	lemma = 'music'
# T173	PUNCT 744 745	,
# #170	AnnotatorNotes T173	lemma = ','
# T174	ADJ 746 754	recorded
# #171	AnnotatorNotes T174	lemma = 'record'
# T175	ADP 755 757	on
# #172	AnnotatorNotes T175	lemma = 'on'
# T176	DET 758 761	the
# #173	AnnotatorNotes T176	lemma = 'the'
# T177	NOUN 762 770	concerts
# #174	AnnotatorNotes T177	lemma = 'concert'
# T178	PUNCT 770 771	.
# #175	AnnotatorNotes T178	lemma = '.'
# T179	ADP 772 774	In
# #176	AnnotatorNotes T179	lemma = 'in'
# T180	DET 775 779	such
# #177	AnnotatorNotes T180	lemma = 'such'
# T181	NOUN 780 783	way
# #178	AnnotatorNotes T181	lemma = 'way'
# T182	PRON 784 786	it
# #179	AnnotatorNotes T182	lemma = 'it'
# T183	VERB 787 792	seems
# #180	AnnotatorNotes T183	lemma = 'seem'
# T184	SCONJ 793 797	that
# #181	AnnotatorNotes T184	lemma = 'that'
# T185	NOUN 798 804	people
# #182	AnnotatorNotes T185	lemma = 'people'
# T186	ADP 805 807	of
# #183	AnnotatorNotes T186	lemma = 'of'
# T187	NOUN 808 811	art
# #184	AnnotatorNotes T187	lemma = 'art'
# T188	VERB 812 821	producing
# #185	AnnotatorNotes T188	lemma = 'producing'
# T189	ADV 822 828	really
# #186	AnnotatorNotes T189	lemma = 'really'
# T190	VERB 829 834	waste
# #187	AnnotatorNotes T190	lemma = 'waste'
# T191	DET 835 840	their
# #188	AnnotatorNotes T191	lemma = 'their'
# T192	NOUN 841 846	money
# #189	AnnotatorNotes T192	lemma = 'money'
# T193	PART 847 849	to
# #190	AnnotatorNotes T193	lemma = 'to'
# T194	VERB 850 856	create
# #191	AnnotatorNotes T194	lemma = 'create'
# T195	DET 857 858	a
# #192	AnnotatorNotes T195	lemma = 'a'
# T196	ADJ 859 863	good
# #193	AnnotatorNotes T196	lemma = 'good'
# T197	ADJ 864 876	proffesional
# #194	AnnotatorNotes T197	lemma = 'proffesional'
# T198	NOUN 877 884	picture
# #195	AnnotatorNotes T198	lemma = 'picture'
# T199	CCONJ 885 887	or
# #196	AnnotatorNotes T199	lemma = 'or'
# T200	NOUN 888 893	sound
# #197	AnnotatorNotes T200	lemma = 'sound'
# T201	PUNCT 893 894	.
# #198	AnnotatorNotes T201	lemma = '.'
# T202	ADP 895 897	On
# #199	AnnotatorNotes T202	lemma = 'on'
# T203	DET 898 901	the
# #200	AnnotatorNotes T203	lemma = 'the'
# T204	ADJ 902 907	other
# #201	AnnotatorNotes T204	lemma = 'other'
# T205	NOUN 908 912	hand
# #202	AnnotatorNotes T205	lemma = 'hand'
# T206	PUNCT 912 913	,
# #203	AnnotatorNotes T206	lemma = ','
# T207	ADP 914 916	in
# #204	AnnotatorNotes T207	lemma = 'in'
# T208	DET 917 920	the
# #205	AnnotatorNotes T208	lemma = 'the'
# T209	NOUN 921 924	era
# #206	AnnotatorNotes T209	lemma = 'era'
# T210	ADP 925 927	of
# #207	AnnotatorNotes T210	lemma = 'of'
# T211	VERB 928 938	developing
# #208	AnnotatorNotes T211	lemma = 'develop'
# T212	NOUN 939 951	technologies
# #209	AnnotatorNotes T212	lemma = 'technology'
# T213	PRON 952 954	it
# #210	AnnotatorNotes T213	lemma = 'it'
# T214	AUX 955 957	is
# #211	AnnotatorNotes T214	lemma = 'be'
# T215	ADV 958 964	really
# #212	AnnotatorNotes T215	lemma = 'really'
# T216	VERB 965 975	convenient
# #213	AnnotatorNotes T216	lemma = 'convenient'
# T217	PART 976 978	to
# #214	AnnotatorNotes T217	lemma = 'to'
# T218	VERB 979 982	use
# #215	AnnotatorNotes T218	lemma = 'use'
# T219	ADJ 983 989	social
# #216	AnnotatorNotes T219	lemma = 'social'
# T220	NOUN 990 998	networks
# #217	AnnotatorNotes T220	lemma = 'network'
# T221	CCONJ 999 1001	or
# #218	AnnotatorNotes T221	lemma = 'or'
# T222	ADJ 1002 1013	specialized
# #219	AnnotatorNotes T222	lemma = 'specialized'
# T223	NOUN 1014 1021	applies
# #220	AnnotatorNotes T223	lemma = 'apply'
# T224	ADP 1022 1024	as
# #221	AnnotatorNotes T224	lemma = 'as'
# T225	DET 1025 1026	a
# #222	AnnotatorNotes T225	lemma = 'a'
# T226	NOUN 1027 1035	platform
# #223	AnnotatorNotes T226	lemma = 'platform'
# T227	PART 1036 1038	to
# #224	AnnotatorNotes T227	lemma = 'to'
# T228	VERB 1039 1044	store
# #225	AnnotatorNotes T228	lemma = 'store'
# T229	ADJ 1045 1050	music
# #226	AnnotatorNotes T229	lemma = 'music'
# T230	NOUN 1051 1063	compositions
# #227	AnnotatorNotes T230	lemma = 'composition'
# T231	CCONJ 1064 1066	or
# #228	AnnotatorNotes T231	lemma = 'or'
# T232	NOUN 1067 1072	films
# #229	AnnotatorNotes T232	lemma = 'film'
# T233	PUNCT 1072 1073	.
# #230	AnnotatorNotes T233	lemma = '.'
# T234	ADV 1074 1078	Thus
# #231	AnnotatorNotes T234	lemma = 'thus'
# T235	PUNCT 1078 1079	,
# #232	AnnotatorNotes T235	lemma = ','
# T236	ADJ 1080 1084	many
# #233	AnnotatorNotes T236	lemma = 'many'
# T237	NOUN 1085 1091	people
# #234	AnnotatorNotes T237	lemma = 'people'
# T238	AUX 1092 1095	are
# #235	AnnotatorNotes T238	lemma = 'be'
# T239	ADJ 1096 1101	ready
# #236	AnnotatorNotes T239	lemma = 'ready'
# T240	PART 1102 1104	to
# #237	AnnotatorNotes T240	lemma = 'to'
# T241	VERB 1105 1111	commit
# #238	AnnotatorNotes T241	lemma = 'commit'
# T242	DET 1112 1113	a
# #239	AnnotatorNotes T242	lemma = 'a'
# T243	NOUN 1114 1117	law
# #240	AnnotatorNotes T243	lemma = 'law'
# T244	CCONJ 1118 1121	and
# #241	AnnotatorNotes T244	lemma = 'and'
# T245	VERB 1122 1126	have
# #242	AnnotatorNotes T245	lemma = 'have'
# T246	DET 1127 1128	a
# #243	AnnotatorNotes T246	lemma = 'a'
# T247	ADJ 1129 1133	free
# #244	AnnotatorNotes T247	lemma = 'free'
# T248	NOUN 1134 1140	wealth
# #245	AnnotatorNotes T248	lemma = 'wealth'
# T249	PUNCT 1140 1141	.
# #246	AnnotatorNotes T249	lemma = '.'
# T250	ADV 1142 1149	However
# #247	AnnotatorNotes T250	lemma = 'however'
# T251	PUNCT 1149 1150	,
# #248	AnnotatorNotes T251	lemma = ','
# T252	DET 1151 1155	this
# #249	AnnotatorNotes T252	lemma = 'this'
# T253	NOUN 1156 1163	problem
# #250	AnnotatorNotes T253	lemma = 'problem'
# T254	AUX 1164 1166	is
# #251	AnnotatorNotes T254	lemma = 'be'
# T255	VERB 1167 1174	decided
# #252	AnnotatorNotes T255	lemma = 'decid'
# T256	ADP 1175 1177	by
# #253	AnnotatorNotes T256	lemma = 'by'
# T257	ADJ 1178 1183	Apple
# #254	AnnotatorNotes T257	lemma = 'Apple'
# T258	NOUN 1184 1195	corporation
# #255	AnnotatorNotes T258	lemma = 'corporation'
# T259	PRON 1196 1201	which
# #256	AnnotatorNotes T259	lemma = 'which'
# T260	AUX 1202 1205	has
# #257	AnnotatorNotes T260	lemma = 'have'
# T261	DET 1206 1207	a
# #258	AnnotatorNotes T261	lemma = 'a'
# T262	ADJ 1208 1212	huge
# #259	AnnotatorNotes T262	lemma = 'huge'
# T263	NOUN 1213 1218	music
# #260	AnnotatorNotes T263	lemma = 'music'
# T264	NOUN 1219 1227	resource
# #261	AnnotatorNotes T264	lemma = 'resource'
# T265	ADJ 1228 1232	free
# #262	AnnotatorNotes T265	lemma = 'free'
# T266	ADP 1233 1236	for
# #263	AnnotatorNotes T266	lemma = 'for'
# T267	NUM 1237 1242	three
# #264	AnnotatorNotes T267	lemma = 'three'
# T268	NOUN 1243 1249	months
# #265	AnnotatorNotes T268	lemma = 'month'
# T269	PUNCT 1249 1250	.
# #266	AnnotatorNotes T269	lemma = '.'
# T270	ADV 1251 1259	Moreover
# #267	AnnotatorNotes T270	lemma = 'moreover'
# T271	PUNCT 1259 1260	,
# #268	AnnotatorNotes T271	lemma = ','
# T272	ADV 1261 1266	there
# #269	AnnotatorNotes T272	lemma = 'there'
# T273	VERB 1267 1269	is
# #270	AnnotatorNotes T273	lemma = 'be'
# T274	DET 1270 1271	a
# #271	AnnotatorNotes T274	lemma = 'a'
# T275	NOUN 1272 1279	problem
# #272	AnnotatorNotes T275	lemma = 'problem'
# T276	ADP 1280 1282	of
# #273	AnnotatorNotes T276	lemma = 'of'
# T277	NOUN 1283 1289	people
# #274	AnnotatorNotes T277	lemma = 'people'
# T278	ADP 1289 1291	’s
# #275	AnnotatorNotes T278	lemma = '’s'
# T279	NOUN 1292 1300	equality
# #276	AnnotatorNotes T279	lemma = 'equality'
# T280	PUNCT 1300 1301	.
# #277	AnnotatorNotes T280	lemma = '.'
# T281	PRON 1302 1304	It
# #278	AnnotatorNotes T281	lemma = 'it'
# T282	AUX 1305 1307	is
# #279	AnnotatorNotes T282	lemma = 'be'
# T283	VERB 1308 1318	considered
# #280	AnnotatorNotes T283	lemma = 'consider'
# T284	SCONJ 1319 1323	that
# #281	AnnotatorNotes T284	lemma = 'that'
# T285	PRON 1324 1332	everyone
# #282	AnnotatorNotes T285	lemma = 'everyone'
# T286	AUX 1333 1339	should
# #283	AnnotatorNotes T286	lemma = 'shall'
# T287	VERB 1340 1344	have
# #284	AnnotatorNotes T287	lemma = 'have'
# T288	DET 1345 1346	a
# #285	AnnotatorNotes T288	lemma = 'a'
# T289	NOUN 1347 1352	right
# #286	AnnotatorNotes T289	lemma = 'right'
# T290	PART 1353 1355	to
# #287	AnnotatorNotes T290	lemma = 'to'
# T291	VERB 1356 1359	use
# #288	AnnotatorNotes T291	lemma = 'use'
# T292	DET 1360 1361	a
# #289	AnnotatorNotes T292	lemma = 'a'
# T293	NOUN 1362 1368	wealth
# #290	AnnotatorNotes T293	lemma = 'wealth'
# T294	PRON 1369 1374	which
# #291	AnnotatorNotes T294	lemma = 'which'
# T295	AUX 1375 1377	is
# #292	AnnotatorNotes T295	lemma = 'be'
# T296	VERB 1378 1382	made
# #293	AnnotatorNotes T296	lemma = 'make'
# T297	CCONJ 1383 1386	and
# #294	AnnotatorNotes T297	lemma = 'and'
# T298	VERB 1387 1395	prepared
# #295	AnnotatorNotes T298	lemma = 'prepare'
# T299	ADP 1396 1398	to
# #296	AnnotatorNotes T299	lemma = 'to'
# T300	ADJ 1399 1405	public
# #297	AnnotatorNotes T300	lemma = 'public'
# T301	PUNCT 1405 1406	.
# #298	AnnotatorNotes T301	lemma = '.'
# T302	ADV 1407 1409	So
# #299	AnnotatorNotes T302	lemma = 'so'
# T303	PUNCT 1409 1410	,
# #300	AnnotatorNotes T303	lemma = ','
# T304	PRON 1411 1413	it
# #301	AnnotatorNotes T304	lemma = 'it'
# T305	AUX 1414 1420	should
# #302	AnnotatorNotes T305	lemma = 'shall'
# T306	AUX 1421 1423	be
# #303	AnnotatorNotes T306	lemma = 'be'
# T307	ADJ 1424 1433	available
# #304	AnnotatorNotes T307	lemma = 'available'
# T308	PART 1434 1437	not
# #305	AnnotatorNotes T308	lemma = 'not'
# T309	ADV 1438 1442	only
# #306	AnnotatorNotes T309	lemma = 'only'
# T310	ADP 1443 1446	for
# #307	AnnotatorNotes T310	lemma = 'for'
# T311	DET 1447 1452	those
# #308	AnnotatorNotes T311	lemma = 'that'
# T312	NOUN 1453 1459	people
# #309	AnnotatorNotes T312	lemma = 'people'
# T313	PRON 1460 1463	who
# #310	AnnotatorNotes T313	lemma = 'who'
# T314	VERB 1464 1468	have
# #311	AnnotatorNotes T314	lemma = 'have'
# T315	DET 1469 1470	a
# #312	AnnotatorNotes T315	lemma = 'a'
# T316	ADJ 1471 1480	financial
# #313	AnnotatorNotes T316	lemma = 'financial'
# T317	NOUN 1481 1492	opportunity
# #314	AnnotatorNotes T317	lemma = 'opportunity'
# T318	PART 1493 1495	to
# #315	AnnotatorNotes T318	lemma = 'to'
# T319	VERB 1496 1499	pay
# #316	AnnotatorNotes T319	lemma = 'pay'
# T320	ADP 1500 1503	for
# #317	AnnotatorNotes T320	lemma = 'for'
# T321	NOUN 1504 1513	listening
# #318	AnnotatorNotes T321	lemma = 'listening'
# T322	ADP 1514 1517	for
# #319	AnnotatorNotes T322	lemma = 'for'
# T323	DET 1518 1519	a
# #320	AnnotatorNotes T323	lemma = 'a'
# T324	NOUN 1520 1525	music
# #321	AnnotatorNotes T324	lemma = 'music'
# T325	CCONJ 1526 1528	or
# #322	AnnotatorNotes T325	lemma = 'or'
# T326	NOUN 1529 1537	watching
# #323	AnnotatorNotes T326	lemma = 'watch'
# T327	NOUN 1538 1543	films
# #324	AnnotatorNotes T327	lemma = 'film'
# T328	PUNCT 1543 1544	.
# #325	AnnotatorNotes T328	lemma = '.'
# T329	ADP 1545 1547	To
# #326	AnnotatorNotes T329	lemma = 'to'
# T330	VERB 1548 1551	sum
# #327	AnnotatorNotes T330	lemma = 'sum'
# T331	ADV 1552 1554	up
# #328	AnnotatorNotes T331	lemma = 'up'
# T332	PUNCT 1554 1555	,
# #329	AnnotatorNotes T332	lemma = ','
# T333	PRON 1556 1558	it
# #330	AnnotatorNotes T333	lemma = 'it'
# T334	AUX 1559 1561	is
# #331	AnnotatorNotes T334	lemma = 'be'
# T335	ADV 1562 1568	really
# #332	AnnotatorNotes T335	lemma = 'really'
# T336	ADJ 1569 1578	important
# #333	AnnotatorNotes T336	lemma = 'important'
# T337	ADP 1579 1582	for
# #334	AnnotatorNotes T337	lemma = 'for'
# T338	NOUN 1583 1592	musicians
# #335	AnnotatorNotes T338	lemma = 'musician'
# T339	CCONJ 1593 1596	and
# #336	AnnotatorNotes T339	lemma = 'and'
# T340	NOUN 1597 1601	film
# #337	AnnotatorNotes T340	lemma = 'film'
# T341	NOUN 1602 1611	producers
# #338	AnnotatorNotes T341	lemma = 'producer'
# T342	PART 1612 1614	to
# #339	AnnotatorNotes T342	lemma = 'to'
# T343	VERB 1615 1620	share
# #340	AnnotatorNotes T343	lemma = 'share'
# T344	DET 1621 1626	their
# #341	AnnotatorNotes T344	lemma = 'their'
# T345	NOUN 1627 1640	“masterpieces
# #342	AnnotatorNotes T345	lemma = '“masterpiece'
# T346	PUNCT 1640 1641	”
# #343	AnnotatorNotes T346	lemma = '”'
# T347	ADP 1642 1646	with
# #344	AnnotatorNotes T347	lemma = 'with'
# T348	DET 1647 1650	all
# #345	AnnotatorNotes T348	lemma = 'all'
# T349	NOUN 1651 1657	people
# #346	AnnotatorNotes T349	lemma = 'people'
# T350	ADP 1658 1660	in
# #347	AnnotatorNotes T350	lemma = 'in'
# T351	ADJ 1661 1666	equal
# #348	AnnotatorNotes T351	lemma = 'equal'
# T352	NOUN 1667 1671	form
# #349	AnnotatorNotes T352	lemma = 'form'
# T353	PUNCT 1671 1672	.
# #350	AnnotatorNotes T353	lemma = '.'
#
# T1	Superlative_adj 16 30	the most great
# #1	AnnotatorNotes T1	greatest
# T2	Defining 49 54	, who
# T3	lex_item_choice 63 82	entertainment items
# #2	AnnotatorNotes T3	entertaining content
# T4	Spelling 111 121	prospecity
# #3	AnnotatorNotes T4	prosperity
# T5	Articles 107 121	the prospecity
# #4	AnnotatorNotes T5	prosperity
# T6	Absence_comp_colloc 174 179	views
# #5	AnnotatorNotes T6	points of view
# T7	Prepositions 216 233	From the one hand
# #6	AnnotatorNotes T7	On the one hand
# T8	Category_confusion 356 364	relaxing
# #7	AnnotatorNotes T8	relaxation
# T9	Articles 412 419	a right
# #8	AnnotatorNotes T9	right
# T10	Punctuation 446 449	and
# #9	AnnotatorNotes T10	, and
# T11	lex_item_choice 529 538	enjoyment
# #10	AnnotatorNotes T11	actions
# T12	Articles 553 591	the copying and sharing music or films
# #11	AnnotatorNotes T12	copying and sharing music or films
# T13	Articles 595 615	of non-original form
# #12	AnnotatorNotes T13	a non-original form
# T14	Category_confusion 624 637	deteriorating
# #13	AnnotatorNotes T14	deterioration
# T15	Prepositions 675 677	of
# #14	AnnotatorNotes T15	for
# T16	Articles 758 770	the concerts
# #15	AnnotatorNotes T16	concerts
# T17	Absence_explanation 681 687	can be
# #16	AnnotatorNotes T17	can be in the accessibility of
# T18	Punctuation 744 745	,
# T19	Redundant_comp 812 821	producing
# A1	Delete T19
# T20	lex_item_choice 822 828	really
# #17	AnnotatorNotes T20	just
# T21	Category_confusion 847 856	to create
# #18	AnnotatorNotes T21	creating
# T22	lex_item_choice 1167 1174	decided
# #19	AnnotatorNotes T22	solved
# T23	Tense_choice 1164 1174	is decided
# #20	AnnotatorNotes T23	was solved
# T24	Often_confused 1196 1201	which
# #21	AnnotatorNotes T24	that
# T25	Absence_explanation 1228 1232	free
# #22	AnnotatorNotes T25	that can be used for free
# T26	Articles 1345 1352	a right
# #23	AnnotatorNotes T26	right
# T27	Absence_explanation 1360 1368	a wealth
# #24	AnnotatorNotes T27	cultural wealth
# T28	Articles 1360 1368	a wealth
# #25	AnnotatorNotes T28	cultural wealth
# T29	Articles 1127 1140	a free wealth
# #26	AnnotatorNotes T29	free cultural wealth
# T30	Absence_explanation 1127 1140	a free wealth
# #27	AnnotatorNotes T30	free cultural wealth
# T31	Absence_explanation 1396 1405	to public
# #28	AnnotatorNotes T31	for public to enjoy it
# T32	Prepositions 1504 1525	listening for a music
# #29	AnnotatorNotes T32	listening to music
# T33	Articles 1518 1525	a music
# #30	AnnotatorNotes T33	music
# T34	Articles 1661 1671	equal form
# #31	AnnotatorNotes T34	an equal form
# T35	note 1671 1672	.
# #32	AnnotatorNotes T35	ABl
# T36	ADV 0 8	Nowadays
# #33	AnnotatorNotes T36	lemma = 'nowadays'
# T37	NUM 9 12	one
# #34	AnnotatorNotes T37	lemma = 'one'
# T38	ADP 13 15	of
# #35	AnnotatorNotes T38	lemma = 'of'
# T39	DET 16 19	the
# #36	AnnotatorNotes T39	lemma = 'the'
# T40	ADV 20 24	most
# #37	AnnotatorNotes T40	lemma = 'most'
# T41	ADJ 25 30	great
# #38	AnnotatorNotes T41	lemma = 'great'
# T42	NOUN 31 39	problems
# #39	AnnotatorNotes T42	lemma = 'problem'
# T43	ADP 40 43	for
# #40	AnnotatorNotes T43	lemma = 'for'
# T44	PRON 44 49	those
# #41	AnnotatorNotes T44	lemma = 'that'
# T45	PUNCT 49 50	,
# #42	AnnotatorNotes T45	lemma = ','
# T46	PRON 51 54	who
# #43	AnnotatorNotes T46	lemma = 'who'
# T47	VERB 55 62	produce
# #44	AnnotatorNotes T47	lemma = 'produce'
# T48	ADJ 63 76	entertainment
# #45	AnnotatorNotes T48	lemma = 'entertainment'
# T49	NOUN 77 82	items
# #46	AnnotatorNotes T49	lemma = 'item'
# T50	ADP 83 87	like
# #47	AnnotatorNotes T50	lemma = 'like'
# T51	NOUN 88 93	music
# #48	AnnotatorNotes T51	lemma = 'music'
# T52	CCONJ 94 97	and
# #49	AnnotatorNotes T52	lemma = 'and'
# T53	NOUN 98 103	films
# #50	AnnotatorNotes T53	lemma = 'film'
# T54	AUX 104 106	is
# #51	AnnotatorNotes T54	lemma = 'be'
# T55	DET 107 110	the
# #52	AnnotatorNotes T55	lemma = 'the'
# T56	NOUN 111 121	prospecity
# #53	AnnotatorNotes T56	lemma = 'prospecity'
# T57	ADP 122 124	of
# #54	AnnotatorNotes T57	lemma = 'of'
# T58	ADJ 125 131	pirate
# #55	AnnotatorNotes T58	lemma = 'pirate'
# T59	NOUN 132 138	copies
# #56	AnnotatorNotes T59	lemma = 'copy'
# T60	ADP 139 141	of
# #57	AnnotatorNotes T60	lemma = 'of'
# T61	DET 142 147	their
# #58	AnnotatorNotes T61	lemma = 'their'
# T62	NOUN 148 156	products
# #59	AnnotatorNotes T62	lemma = 'product'
# T63	PUNCT 156 157	.
# #60	AnnotatorNotes T63	lemma = '.'
# T64	ADV 158 160	So
# #61	AnnotatorNotes T64	lemma = 'so'
# T65	PUNCT 160 161	,
# #62	AnnotatorNotes T65	lemma = ','
# T66	ADV 162 167	there
# #63	AnnotatorNotes T66	lemma = 'there'
# T67	VERB 168 171	are
# #64	AnnotatorNotes T67	lemma = 'be'
# T68	NUM 172 173	2
# #65	AnnotatorNotes T68	lemma = '2'
# T69	NOUN 174 179	views
# #66	AnnotatorNotes T69	lemma = 'view'
# T70	ADP 180 182	on
# #67	AnnotatorNotes T70	lemma = 'on'
# T71	DET 183 186	the
# #68	AnnotatorNotes T71	lemma = 'the'
# T72	NOUN 187 196	existence
# #69	AnnotatorNotes T72	lemma = 'existence'
# T73	ADP 197 199	of
# #70	AnnotatorNotes T73	lemma = 'of'
# T74	DET 200 204	such
# #71	AnnotatorNotes T74	lemma = 'such'
# T75	NOUN 205 214	phenomena
# #72	AnnotatorNotes T75	lemma = 'phenomena'
# T76	PUNCT 214 215	.
# #73	AnnotatorNotes T76	lemma = '.'
# T77	ADP 216 220	From
# #74	AnnotatorNotes T77	lemma = 'from'
# T78	DET 221 224	the
# #75	AnnotatorNotes T78	lemma = 'the'
# T79	NUM 225 228	one
# #76	AnnotatorNotes T79	lemma = 'one'
# T80	NOUN 229 233	hand
# #77	AnnotatorNotes T80	lemma = 'hand'
# T81	PUNCT 233 234	,
# #78	AnnotatorNotes T81	lemma = ','
# T82	PRON 235 243	everyone
# #79	AnnotatorNotes T82	lemma = 'everyone'
# T83	AUX 244 250	should
# #80	AnnotatorNotes T83	lemma = 'shall'
# T84	VERB 251 258	respect
# #81	AnnotatorNotes T84	lemma = 'respect'
# T85	DET 259 263	such
# #82	AnnotatorNotes T85	lemma = 'such'
# T86	ADJ 264 272	talented
# #83	AnnotatorNotes T86	lemma = 'talent'
# T87	NOUN 273 279	people
# #84	AnnotatorNotes T87	lemma = 'people'
# T88	ADP 280 282	as
# #85	AnnotatorNotes T88	lemma = 'as'
# T89	NOUN 283 292	musicians
# #86	AnnotatorNotes T89	lemma = 'musician'
# T90	CCONJ 293 296	and
# #87	AnnotatorNotes T90	lemma = 'and'
# T91	NOUN 297 306	producers
# #88	AnnotatorNotes T91	lemma = 'producer'
# T92	PRON 307 310	who
# #89	AnnotatorNotes T92	lemma = 'who'
# T93	VERB 311 318	provide
# #90	AnnotatorNotes T93	lemma = 'provide'
# T94	PRON 319 321	us
# #91	AnnotatorNotes T94	lemma = 'us'
# T95	ADP 322 326	with
# #92	AnnotatorNotes T95	lemma = 'with'
# T96	ADV 327 333	really
# #93	AnnotatorNotes T96	lemma = 'really'
# T97	ADJ 334 340	useful
# #94	AnnotatorNotes T97	lemma = 'useful'
# T98	NOUN 341 347	things
# #95	AnnotatorNotes T98	lemma = 'thing'
# T99	ADP 348 351	for
# #96	AnnotatorNotes T99	lemma = 'for'
# T100	DET 352 355	our
# #97	AnnotatorNotes T100	lemma = 'us'
# T101	NOUN 356 364	relaxing
# #98	AnnotatorNotes T101	lemma = 'relaxing'
# T102	CCONJ 365 367	or
# #99	AnnotatorNotes T102	lemma = 'or'
# T103	ADJ 368 378	scientific
# #100	AnnotatorNotes T103	lemma = 'scientific'
# T104	NOUN 379 389	satisfying
# #101	AnnotatorNotes T104	lemma = 'satisfy'
# T105	PUNCT 389 390	.
# #102	AnnotatorNotes T105	lemma = '.'
# T106	ADV 391 395	Thus
# #103	AnnotatorNotes T106	lemma = 'thus'
# T107	PUNCT 395 396	,
# #104	AnnotatorNotes T107	lemma = ','
# T108	PRON 397 401	they
# #105	AnnotatorNotes T108	lemma = 'they'
# T109	AUX 402 406	must
# #106	AnnotatorNotes T109	lemma = 'must'
# T110	VERB 407 411	have
# #107	AnnotatorNotes T110	lemma = 'have'
# T111	DET 412 413	a
# #108	AnnotatorNotes T111	lemma = 'a'
# T112	NOUN 414 419	right
# #109	AnnotatorNotes T112	lemma = 'right'
# T113	PART 420 422	to
# #110	AnnotatorNotes T113	lemma = 'to'
# T114	AUX 423 425	be
# #111	AnnotatorNotes T114	lemma = 'be'
# T115	VERB 426 430	paid
# #112	AnnotatorNotes T115	lemma = 'pay'
# T116	ADP 431 434	for
# #113	AnnotatorNotes T116	lemma = 'for'
# T117	DET 435 440	their
# #114	AnnotatorNotes T117	lemma = 'their'
# T118	NOUN 441 445	work
# #115	AnnotatorNotes T118	lemma = 'work'
# T119	CCONJ 446 449	and
# #116	AnnotatorNotes T119	lemma = 'and'
# T120	NOUN 450 455	users
# #117	AnnotatorNotes T120	lemma = 'user'
# T121	ADP 456 458	of
# #118	AnnotatorNotes T121	lemma = 'of'
# T122	DET 459 462	the
# #119	AnnotatorNotes T122	lemma = 'the'
# T123	NOUN 463 471	Internet
# #120	AnnotatorNotes T123	lemma = 'internet'
# T124	PRON 472 475	who
# #121	AnnotatorNotes T124	lemma = 'who'
# T125	VERB 476 484	download
# #122	AnnotatorNotes T125	lemma = 'download'
# T126	NOUN 485 491	pirate
# #123	AnnotatorNotes T126	lemma = 'pirate'
# T127	NOUN 492 497	files
# #124	AnnotatorNotes T127	lemma = 'file'
# T128	AUX 498 504	should
# #125	AnnotatorNotes T128	lemma = 'shall'
# T129	AUX 505 507	be
# #126	AnnotatorNotes T129	lemma = 'be'
# T130	VERB 508 516	punished
# #127	AnnotatorNotes T130	lemma = 'punish'
# T131	ADP 517 520	for
# #128	AnnotatorNotes T131	lemma = 'for'
# T132	ADJ 521 528	illegal
# #129	AnnotatorNotes T132	lemma = 'illegal'
# T133	NOUN 529 538	enjoyment
# #130	AnnotatorNotes T133	lemma = 'enjoyment'
# T134	PUNCT 538 539	.
# #131	AnnotatorNotes T134	lemma = '.'
# T135	ADV 540 551	Furthermore
# #132	AnnotatorNotes T135	lemma = 'furthermore'
# T136	PUNCT 551 552	,
# #133	AnnotatorNotes T136	lemma = ','
# T137	DET 553 556	the
# #134	AnnotatorNotes T137	lemma = 'the'
# T138	VERB 557 564	copying
# #135	AnnotatorNotes T138	lemma = 'copy'
# T139	CCONJ 565 568	and
# #136	AnnotatorNotes T139	lemma = 'and'
# T140	VERB 569 576	sharing
# #137	AnnotatorNotes T140	lemma = 'shar'
# T141	NOUN 577 582	music
# #138	AnnotatorNotes T141	lemma = 'music'
# T142	CCONJ 583 585	or
# #139	AnnotatorNotes T142	lemma = 'or'
# T143	NOUN 586 591	films
# #140	AnnotatorNotes T143	lemma = 'film'
# T144	ADP 592 594	in
# #141	AnnotatorNotes T144	lemma = 'in'
# T145	ADP 595 597	of
# #142	AnnotatorNotes T145	lemma = 'of'
# T146	ADV 598 601	non
# #143	AnnotatorNotes T146	lemma = 'non'
# T147	PUNCT 601 602	-
# #144	AnnotatorNotes T147	lemma = '-'
# T148	ADJ 602 610	original
# #145	AnnotatorNotes T148	lemma = 'original'
# T149	NOUN 611 615	form
# #146	AnnotatorNotes T149	lemma = 'form'
# T150	NOUN 616 620	lead
# #147	AnnotatorNotes T150	lemma = 'lead'
# T151	ADP 621 623	to
# #148	AnnotatorNotes T151	lemma = 'to'
# T152	NOUN 624 637	deteriorating
# #149	AnnotatorNotes T152	lemma = 'deteriorate'
# T153	ADP 638 640	of
# #150	AnnotatorNotes T153	lemma = 'of'
# T154	DET 641 644	the
# #151	AnnotatorNotes T154	lemma = 'the'
# T155	NOUN 645 653	products
# #152	AnnotatorNotes T155	lemma = 'product'
# T156	ADP 653 654	’
# #153	AnnotatorNotes T156	lemma = '''
# T157	NOUN 655 662	quality
# #154	AnnotatorNotes T157	lemma = 'quality'
# T158	PUNCT 662 663	.
# #155	AnnotatorNotes T158	lemma = '.'
# T159	DET 664 667	The
# #156	AnnotatorNotes T159	lemma = 'the'
# T160	NOUN 668 674	reason
# #157	AnnotatorNotes T160	lemma = 'reason'
# T161	ADP 675 677	of
# #158	AnnotatorNotes T161	lemma = 'of'
# T162	PRON 678 680	it
# #159	AnnotatorNotes T162	lemma = 'it'
# T163	AUX 681 684	can
# #160	AnnotatorNotes T163	lemma = 'can'
# T164	AUX 685 687	be
# #161	AnnotatorNotes T164	lemma = 'be'
# T165	ADV 688 693	films
# #162	AnnotatorNotes T165	lemma = 'film'
# T166	VERB 694 702	recorded
# #163	AnnotatorNotes T166	lemma = 'record'
# T167	ADP 703 705	on
# #164	AnnotatorNotes T167	lemma = 'on'
# T168	NOUN 706 718	videocameras
# #165	AnnotatorNotes T168	lemma = 'videocamera'
# T169	ADP 719 723	from
# #166	AnnotatorNotes T169	lemma = 'from'
# T170	NOUN 724 735	cinemaparks
# #167	AnnotatorNotes T170	lemma = 'cinemapark'
# T171	CCONJ 736 738	or
# #168	AnnotatorNotes T171	lemma = 'or'
# T172	NOUN 739 744	music
# #169	AnnotatorNotes T172	lemma = 'music'
# T173	PUNCT 744 745	,
# #170	AnnotatorNotes T173	lemma = ','
# T174	ADJ 746 754	recorded
# #171	AnnotatorNotes T174	lemma = 'record'
# T175	ADP 755 757	on
# #172	AnnotatorNotes T175	lemma = 'on'
# T176	DET 758 761	the
# #173	AnnotatorNotes T176	lemma = 'the'
# T177	NOUN 762 770	concerts
# #174	AnnotatorNotes T177	lemma = 'concert'
# T178	PUNCT 770 771	.
# #175	AnnotatorNotes T178	lemma = '.'
# T179	ADP 772 774	In
# #176	AnnotatorNotes T179	lemma = 'in'
# T180	DET 775 779	such
# #177	AnnotatorNotes T180	lemma = 'such'
# T181	NOUN 780 783	way
# #178	AnnotatorNotes T181	lemma = 'way'
# T182	PRON 784 786	it
# #179	AnnotatorNotes T182	lemma = 'it'
# T183	VERB 787 792	seems
# #180	AnnotatorNotes T183	lemma = 'seem'
# T184	SCONJ 793 797	that
# #181	AnnotatorNotes T184	lemma = 'that'
# T185	NOUN 798 804	people
# #182	AnnotatorNotes T185	lemma = 'people'
# T186	ADP 805 807	of
# #183	AnnotatorNotes T186	lemma = 'of'
# T187	NOUN 808 811	art
# #184	AnnotatorNotes T187	lemma = 'art'
# T188	VERB 812 821	producing
# #185	AnnotatorNotes T188	lemma = 'producing'
# T189	ADV 822 828	really
# #186	AnnotatorNotes T189	lemma = 'really'
# T190	VERB 829 834	waste
# #187	AnnotatorNotes T190	lemma = 'waste'
# T191	DET 835 840	their
# #188	AnnotatorNotes T191	lemma = 'their'
# T192	NOUN 841 846	money
# #189	AnnotatorNotes T192	lemma = 'money'
# T193	PART 847 849	to
# #190	AnnotatorNotes T193	lemma = 'to'
# T194	VERB 850 856	create
# #191	AnnotatorNotes T194	lemma = 'create'
# T195	DET 857 858	a
# #192	AnnotatorNotes T195	lemma = 'a'
# T196	ADJ 859 863	good
# #193	AnnotatorNotes T196	lemma = 'good'
# T197	ADJ 864 876	proffesional
# #194	AnnotatorNotes T197	lemma = 'proffesional'
# T198	NOUN 877 884	picture
# #195	AnnotatorNotes T198	lemma = 'picture'
# T199	CCONJ 885 887	or
# #196	AnnotatorNotes T199	lemma = 'or'
# T200	NOUN 888 893	sound
# #197	AnnotatorNotes T200	lemma = 'sound'
# T201	PUNCT 893 894	.
# #198	AnnotatorNotes T201	lemma = '.'
# T202	ADP 895 897	On
# #199	AnnotatorNotes T202	lemma = 'on'
# T203	DET 898 901	the
# #200	AnnotatorNotes T203	lemma = 'the'
# T204	ADJ 902 907	other
# #201	AnnotatorNotes T204	lemma = 'other'
# T205	NOUN 908 912	hand
# #202	AnnotatorNotes T205	lemma = 'hand'
# T206	PUNCT 912 913	,
# #203	AnnotatorNotes T206	lemma = ','
# T207	ADP 914 916	in
# #204	AnnotatorNotes T207	lemma = 'in'
# T208	DET 917 920	the
# #205	AnnotatorNotes T208	lemma = 'the'
# T209	NOUN 921 924	era
# #206	AnnotatorNotes T209	lemma = 'era'
# T210	ADP 925 927	of
# #207	AnnotatorNotes T210	lemma = 'of'
# T211	VERB 928 938	developing
# #208	AnnotatorNotes T211	lemma = 'develop'
# T212	NOUN 939 951	technologies
# #209	AnnotatorNotes T212	lemma = 'technology'
# T213	PRON 952 954	it
# #210	AnnotatorNotes T213	lemma = 'it'
# T214	AUX 955 957	is
# #211	AnnotatorNotes T214	lemma = 'be'
# T215	ADV 958 964	really
# #212	AnnotatorNotes T215	lemma = 'really'
# T216	VERB 965 975	convenient
# #213	AnnotatorNotes T216	lemma = 'convenient'
# T217	PART 976 978	to
# #214	AnnotatorNotes T217	lemma = 'to'
# T218	VERB 979 982	use
# #215	AnnotatorNotes T218	lemma = 'use'
# T219	ADJ 983 989	social
# #216	AnnotatorNotes T219	lemma = 'social'
# T220	NOUN 990 998	networks
# #217	AnnotatorNotes T220	lemma = 'network'
# T221	CCONJ 999 1001	or
# #218	AnnotatorNotes T221	lemma = 'or'
# T222	ADJ 1002 1013	specialized
# #219	AnnotatorNotes T222	lemma = 'specialized'
# T223	NOUN 1014 1021	applies
# #220	AnnotatorNotes T223	lemma = 'apply'
# T224	ADP 1022 1024	as
# #221	AnnotatorNotes T224	lemma = 'as'
# T225	DET 1025 1026	a
# #222	AnnotatorNotes T225	lemma = 'a'
# T226	NOUN 1027 1035	platform
# #223	AnnotatorNotes T226	lemma = 'platform'
# T227	PART 1036 1038	to
# #224	AnnotatorNotes T227	lemma = 'to'
# T228	VERB 1039 1044	store
# #225	AnnotatorNotes T228	lemma = 'store'
# T229	ADJ 1045 1050	music
# #226	AnnotatorNotes T229	lemma = 'music'
# T230	NOUN 1051 1063	compositions
# #227	AnnotatorNotes T230	lemma = 'composition'
# T231	CCONJ 1064 1066	or
# #228	AnnotatorNotes T231	lemma = 'or'
# T232	NOUN 1067 1072	films
# #229	AnnotatorNotes T232	lemma = 'film'
# T233	PUNCT 1072 1073	.
# #230	AnnotatorNotes T233	lemma = '.'
# T234	ADV 1074 1078	Thus
# #231	AnnotatorNotes T234	lemma = 'thus'
# T235	PUNCT 1078 1079	,
# #232	AnnotatorNotes T235	lemma = ','
# T236	ADJ 1080 1084	many
# #233	AnnotatorNotes T236	lemma = 'many'
# T237	NOUN 1085 1091	people
# #234	AnnotatorNotes T237	lemma = 'people'
# T238	AUX 1092 1095	are
# #235	AnnotatorNotes T238	lemma = 'be'
# T239	ADJ 1096 1101	ready
# #236	AnnotatorNotes T239	lemma = 'ready'
# T240	PART 1102 1104	to
# #237	AnnotatorNotes T240	lemma = 'to'
# T241	VERB 1105 1111	commit
# #238	AnnotatorNotes T241	lemma = 'commit'
# T242	DET 1112 1113	a
# #239	AnnotatorNotes T242	lemma = 'a'
# T243	NOUN 1114 1117	law
# #240	AnnotatorNotes T243	lemma = 'law'
# T244	CCONJ 1118 1121	and
# #241	AnnotatorNotes T244	lemma = 'and'
# T245	VERB 1122 1126	have
# #242	AnnotatorNotes T245	lemma = 'have'
# T246	DET 1127 1128	a
# #243	AnnotatorNotes T246	lemma = 'a'
# T247	ADJ 1129 1133	free
# #244	AnnotatorNotes T247	lemma = 'free'
# T248	NOUN 1134 1140	wealth
# #245	AnnotatorNotes T248	lemma = 'wealth'
# T249	PUNCT 1140 1141	.
# #246	AnnotatorNotes T249	lemma = '.'
# T250	ADV 1142 1149	However
# #247	AnnotatorNotes T250	lemma = 'however'
# T251	PUNCT 1149 1150	,
# #248	AnnotatorNotes T251	lemma = ','
# T252	DET 1151 1155	this
# #249	AnnotatorNotes T252	lemma = 'this'
# T253	NOUN 1156 1163	problem
# #250	AnnotatorNotes T253	lemma = 'problem'
# T254	AUX 1164 1166	is
# #251	AnnotatorNotes T254	lemma = 'be'
# T255	VERB 1167 1174	decided
# #252	AnnotatorNotes T255	lemma = 'decid'
# T256	ADP 1175 1177	by
# #253	AnnotatorNotes T256	lemma = 'by'
# T257	ADJ 1178 1183	Apple
# #254	AnnotatorNotes T257	lemma = 'Apple'
# T258	NOUN 1184 1195	corporation
# #255	AnnotatorNotes T258	lemma = 'corporation'
# T259	PRON 1196 1201	which
# #256	AnnotatorNotes T259	lemma = 'which'
# T260	AUX 1202 1205	has
# #257	AnnotatorNotes T260	lemma = 'have'
# T261	DET 1206 1207	a
# #258	AnnotatorNotes T261	lemma = 'a'
# T262	ADJ 1208 1212	huge
# #259	AnnotatorNotes T262	lemma = 'huge'
# T263	NOUN 1213 1218	music
# #260	AnnotatorNotes T263	lemma = 'music'
# T264	NOUN 1219 1227	resource
# #261	AnnotatorNotes T264	lemma = 'resource'
# T265	ADJ 1228 1232	free
# #262	AnnotatorNotes T265	lemma = 'free'
# T266	ADP 1233 1236	for
# #263	AnnotatorNotes T266	lemma = 'for'
# T267	NUM 1237 1242	three
# #264	AnnotatorNotes T267	lemma = 'three'
# T268	NOUN 1243 1249	months
# #265	AnnotatorNotes T268	lemma = 'month'
# T269	PUNCT 1249 1250	.
# #266	AnnotatorNotes T269	lemma = '.'
# T270	ADV 1251 1259	Moreover
# #267	AnnotatorNotes T270	lemma = 'moreover'
# T271	PUNCT 1259 1260	,
# #268	AnnotatorNotes T271	lemma = ','
# T272	ADV 1261 1266	there
# #269	AnnotatorNotes T272	lemma = 'there'
# T273	VERB 1267 1269	is
# #270	AnnotatorNotes T273	lemma = 'be'
# T274	DET 1270 1271	a
# #271	AnnotatorNotes T274	lemma = 'a'
# T275	NOUN 1272 1279	problem
# #272	AnnotatorNotes T275	lemma = 'problem'
# T276	ADP 1280 1282	of
# #273	AnnotatorNotes T276	lemma = 'of'
# T277	NOUN 1283 1289	people
# #274	AnnotatorNotes T277	lemma = 'people'
# T278	ADP 1289 1291	’s
# #275	AnnotatorNotes T278	lemma = '’s'
# T279	NOUN 1292 1300	equality
# #276	AnnotatorNotes T279	lemma = 'equality'
# T280	PUNCT 1300 1301	.
# #277	AnnotatorNotes T280	lemma = '.'
# T281	PRON 1302 1304	It
# #278	AnnotatorNotes T281	lemma = 'it'
# T282	AUX 1305 1307	is
# #279	AnnotatorNotes T282	lemma = 'be'
# T283	VERB 1308 1318	considered
# #280	AnnotatorNotes T283	lemma = 'consider'
# T284	SCONJ 1319 1323	that
# #281	AnnotatorNotes T284	lemma = 'that'
# T285	PRON 1324 1332	everyone
# #282	AnnotatorNotes T285	lemma = 'everyone'
# T286	AUX 1333 1339	should
# #283	AnnotatorNotes T286	lemma = 'shall'
# T287	VERB 1340 1344	have
# #284	AnnotatorNotes T287	lemma = 'have'
# T288	DET 1345 1346	a
# #285	AnnotatorNotes T288	lemma = 'a'
# T289	NOUN 1347 1352	right
# #286	AnnotatorNotes T289	lemma = 'right'
# T290	PART 1353 1355	to
# #287	AnnotatorNotes T290	lemma = 'to'
# T291	VERB 1356 1359	use
# #288	AnnotatorNotes T291	lemma = 'use'
# T292	DET 1360 1361	a
# #289	AnnotatorNotes T292	lemma = 'a'
# T293	NOUN 1362 1368	wealth
# #290	AnnotatorNotes T293	lemma = 'wealth'
# T294	PRON 1369 1374	which
# #291	AnnotatorNotes T294	lemma = 'which'
# T295	AUX 1375 1377	is
# #292	AnnotatorNotes T295	lemma = 'be'
# T296	VERB 1378 1382	made
# #293	AnnotatorNotes T296	lemma = 'make'
# T297	CCONJ 1383 1386	and
# #294	AnnotatorNotes T297	lemma = 'and'
# T298	VERB 1387 1395	prepared
# #295	AnnotatorNotes T298	lemma = 'prepare'
# T299	ADP 1396 1398	to
# #296	AnnotatorNotes T299	lemma = 'to'
# T300	ADJ 1399 1405	public
# #297	AnnotatorNotes T300	lemma = 'public'
# T301	PUNCT 1405 1406	.
# #298	AnnotatorNotes T301	lemma = '.'
# T302	ADV 1407 1409	So
# #299	AnnotatorNotes T302	lemma = 'so'
# T303	PUNCT 1409 1410	,
# #300	AnnotatorNotes T303	lemma = ','
# T304	PRON 1411 1413	it
# #301	AnnotatorNotes T304	lemma = 'it'
# T305	AUX 1414 1420	should
# #302	AnnotatorNotes T305	lemma = 'shall'
# T306	AUX 1421 1423	be
# #303	AnnotatorNotes T306	lemma = 'be'
# T307	ADJ 1424 1433	available
# #304	AnnotatorNotes T307	lemma = 'available'
# T308	PART 1434 1437	not
# #305	AnnotatorNotes T308	lemma = 'not'
# T309	ADV 1438 1442	only
# #306	AnnotatorNotes T309	lemma = 'only'
# T310	ADP 1443 1446	for
# #307	AnnotatorNotes T310	lemma = 'for'
# T311	DET 1447 1452	those
# #308	AnnotatorNotes T311	lemma = 'that'
# T312	NOUN 1453 1459	people
# #309	AnnotatorNotes T312	lemma = 'people'
# T313	PRON 1460 1463	who
# #310	AnnotatorNotes T313	lemma = 'who'
# T314	VERB 1464 1468	have
# #311	AnnotatorNotes T314	lemma = 'have'
# T315	DET 1469 1470	a
# #312	AnnotatorNotes T315	lemma = 'a'
# T316	ADJ 1471 1480	financial
# #313	AnnotatorNotes T316	lemma = 'financial'
# T317	NOUN 1481 1492	opportunity
# #314	AnnotatorNotes T317	lemma = 'opportunity'
# T318	PART 1493 1495	to
# #315	AnnotatorNotes T318	lemma = 'to'
# T319	VERB 1496 1499	pay
# #316	AnnotatorNotes T319	lemma = 'pay'
# T320	ADP 1500 1503	for
# #317	AnnotatorNotes T320	lemma = 'for'
# T321	NOUN 1504 1513	listening
# #318	AnnotatorNotes T321	lemma = 'listening'
# T322	ADP 1514 1517	for
# #319	AnnotatorNotes T322	lemma = 'for'
# T323	DET 1518 1519	a
# #320	AnnotatorNotes T323	lemma = 'a'
# T324	NOUN 1520 1525	music
# #321	AnnotatorNotes T324	lemma = 'music'
# T325	CCONJ 1526 1528	or
# #322	AnnotatorNotes T325	lemma = 'or'
# T326	NOUN 1529 1537	watching
# #323	AnnotatorNotes T326	lemma = 'watch'
# T327	NOUN 1538 1543	films
# #324	AnnotatorNotes T327	lemma = 'film'
# T328	PUNCT 1543 1544	.
# #325	AnnotatorNotes T328	lemma = '.'
# T329	ADP 1545 1547	To
# #326	AnnotatorNotes T329	lemma = 'to'
# T330	VERB 1548 1551	sum
# #327	AnnotatorNotes T330	lemma = 'sum'
# T331	ADV 1552 1554	up
# #328	AnnotatorNotes T331	lemma = 'up'
# T332	PUNCT 1554 1555	,
# #329	AnnotatorNotes T332	lemma = ','
# T333	PRON 1556 1558	it
# #330	AnnotatorNotes T333	lemma = 'it'
# T334	AUX 1559 1561	is
# #331	AnnotatorNotes T334	lemma = 'be'
# T335	ADV 1562 1568	really
# #332	AnnotatorNotes T335	lemma = 'really'
# T336	ADJ 1569 1578	important
# #333	AnnotatorNotes T336	lemma = 'important'
# T337	ADP 1579 1582	for
# #334	AnnotatorNotes T337	lemma = 'for'
# T338	NOUN 1583 1592	musicians
# #335	AnnotatorNotes T338	lemma = 'musician'
# T339	CCONJ 1593 1596	and
# #336	AnnotatorNotes T339	lemma = 'and'
# T340	NOUN 1597 1601	film
# #337	AnnotatorNotes T340	lemma = 'film'
# T341	NOUN 1602 1611	producers
# #338	AnnotatorNotes T341	lemma = 'producer'
# T342	PART 1612 1614	to
# #339	AnnotatorNotes T342	lemma = 'to'
# T343	VERB 1615 1620	share
# #340	AnnotatorNotes T343	lemma = 'share'
# T344	DET 1621 1626	their
# #341	AnnotatorNotes T344	lemma = 'their'
# T345	NOUN 1627 1640	“masterpieces
# #342	AnnotatorNotes T345	lemma = '“masterpiece'
# T346	PUNCT 1640 1641	”
# #343	AnnotatorNotes T346	lemma = '”'
# T347	ADP 1642 1646	with
# #344	AnnotatorNotes T347	lemma = 'with'
# T348	DET 1647 1650	all
# #345	AnnotatorNotes T348	lemma = 'all'
# T349	NOUN 1651 1657	people
# #346	AnnotatorNotes T349	lemma = 'people'
# T350	ADP 1658 1660	in
# #347	AnnotatorNotes T350	lemma = 'in'
# T351	ADJ 1661 1666	equal
# #348	AnnotatorNotes T351	lemma = 'equal'
# T352	NOUN 1667 1671	form
# #349	AnnotatorNotes T352	lemma = 'form'
# T353	PUNCT 1671 1672	.
# #350	AnnotatorNotes T353	lemma = '.'
#
# T1	Superlative_adj 16 30	the most great
# #1	AnnotatorNotes T1	greatest
# T2	Defining 49 54	, who
# T3	lex_item_choice 63 82	entertainment items
# #2	AnnotatorNotes T3	entertaining content
# T4	Spelling 111 121	prospecity
# #3	AnnotatorNotes T4	prosperity
# T5	Articles 107 121	the prospecity
# #4	AnnotatorNotes T5	prosperity
# T6	Absence_comp_colloc 174 179	views
# #5	AnnotatorNotes T6	points of view
# T7	Prepositions 216 233	From the one hand
# #6	AnnotatorNotes T7	On the one hand
# T8	Category_confusion 356 364	relaxing
# #7	AnnotatorNotes T8	relaxation
# T9	Articles 412 419	a right
# #8	AnnotatorNotes T9	right
# T10	Punctuation 446 449	and
# #9	AnnotatorNotes T10	, and
# T11	lex_item_choice 529 538	enjoyment
# #10	AnnotatorNotes T11	actions
# T12	Articles 553 591	the copying and sharing music or films
# #11	AnnotatorNotes T12	copying and sharing music or films
# T13	Articles 595 615	of non-original form
# #12	AnnotatorNotes T13	a non-original form
# T14	Category_confusion 624 637	deteriorating
# #13	AnnotatorNotes T14	deterioration
# T15	Prepositions 675 677	of
# #14	AnnotatorNotes T15	for
# T16	Articles 758 770	the concerts
# #15	AnnotatorNotes T16	concerts
# T17	Absence_explanation 681 687	can be
# #16	AnnotatorNotes T17	can be in the accessibility of
# T18	Punctuation 744 745	,
# T19	Redundant_comp 812 821	producing
# A1	Delete T19
# T20	lex_item_choice 822 828	really
# #17	AnnotatorNotes T20	just
# T21	Category_confusion 847 856	to create
# #18	AnnotatorNotes T21	creating
# T22	lex_item_choice 1167 1174	decided
# #19	AnnotatorNotes T22	solved
# T23	Tense_choice 1164 1174	is decided
# #20	AnnotatorNotes T23	was solved
# T24	Often_confused 1196 1201	which
# #21	AnnotatorNotes T24	that
# T25	Absence_explanation 1228 1232	free
# #22	AnnotatorNotes T25	that can be used for free
# T26	Articles 1345 1352	a right
# #23	AnnotatorNotes T26	right
# T27	Absence_explanation 1360 1368	a wealth
# #24	AnnotatorNotes T27	cultural wealth
# T28	Articles 1360 1368	a wealth
# #25	AnnotatorNotes T28	cultural wealth
# T29	Articles 1127 1140	a free wealth
# #26	AnnotatorNotes T29	free cultural wealth
# T30	Absence_explanation 1127 1140	a free wealth
# #27	AnnotatorNotes T30	free cultural wealth
# T31	Absence_explanation 1396 1405	to public
# #28	AnnotatorNotes T31	for public to enjoy it
# T32	Prepositions 1504 1525	listening for a music
# #29	AnnotatorNotes T32	listening to music
# T33	Articles 1518 1525	a music
# #30	AnnotatorNotes T33	music
# T34	Articles 1661 1671	equal form
# #31	AnnotatorNotes T34	an equal form
# T35	note 1671 1672	.
# #32	AnnotatorNotes T35	ABl
# T36	ADV 0 8	Nowadays
# #33	AnnotatorNotes T36	lemma = 'nowadays'
# T37	NUM 9 12	one
# #34	AnnotatorNotes T37	lemma = 'one'
# T38	ADP 13 15	of
# #35	AnnotatorNotes T38	lemma = 'of'
# T39	DET 16 19	the
# #36	AnnotatorNotes T39	lemma = 'the'
# T40	ADV 20 24	most
# #37	AnnotatorNotes T40	lemma = 'most'
# T41	ADJ 25 30	great
# #38	AnnotatorNotes T41	lemma = 'great'
# ...
# T105	PUNCT 389 390	.
# #102	AnnotatorNotes T105	lemma = '.'
# T106	ADV 391 395	Thus
# #103	AnnotatorNotes T106	lemma = 'thus'
# T107	PUNCT 395 396	,
# #104	AnnotatorNotes T107	lemma = ','
# T108	PRON 397 401	they
# #105	AnnotatorNotes T108	lemma = 'they'
# T109	AUX 402 406	must
# #106	AnnotatorNotes T109	lemma = 'must'
# T110	VERB 407 411	have
# #107	AnnotatorNotes T110	lemma = 'have'
# T111	DET 412 413	a
# #108	AnnotatorNotes T111	lemma = 'a'
# T112	NOUN 414 419	right
# #109	AnnotatorNotes T112	lemma = 'right'
# T113	PART 420 422	to
# #110	AnnotatorNotes T113	lemma = 'to'
# T114	AUX 423 425	be
# #111	AnnotatorNotes T114	lemma = 'be'
# T115	VERB 426 430	paid
# #112	AnnotatorNotes T115	lemma = 'pay'
# T116	ADP 431 434	for
# #113	AnnotatorNotes T116	lemma = 'for'
# T117	DET 435 440	their
# #114	AnnotatorNotes T117	lemma = 'their'
# T118	NOUN 441 445	work
# #115	AnnotatorNotes T118	lemma = 'work'
# T119	CCONJ 446 449	and
# #116	AnnotatorNotes T119	lemma = 'and'
# T120	NOUN 450 455	users
# #117	AnnotatorNotes T120	lemma = 'user'
# T121	ADP 456 458	of
# #118	AnnotatorNotes T121	lemma = 'of'
# T122	DET 459 462	the
# #119	AnnotatorNotes T122	lemma = 'the'
# T123	NOUN 463 471	Internet
# #120	AnnotatorNotes T123	lemma = 'internet'
# T124	PRON 472 475	who
# #121	AnnotatorNotes T124	lemma = 'who'
# T125	VERB 476 484	download
# #122	AnnotatorNotes T125	lemma = 'download'
# T126	NOUN 485 491	pirate
# #123	AnnotatorNotes T126	lemma = 'pirate'
# T127	NOUN 492 497	files
# #124	AnnotatorNotes T127	lemma = 'file'
# T128	AUX 498 504	should
# #125	AnnotatorNotes T128	lemma = 'shall'
# T129	AUX 505 507	be
# #126	AnnotatorNotes T129	lemma = 'be'
# T130	VERB 508 516	punished
# #127	AnnotatorNotes T130	lemma = 'punish'
# T131	ADP 517 520	for
# #128	AnnotatorNotes T131	lemma = 'for'
# T132	ADJ 521 528	illegal
# #129	AnnotatorNotes T132	lemma = 'illegal'
# T133	NOUN 529 538	enjoyment
# #130	AnnotatorNotes T133	lemma = 'enjoyment'
# T134	PUNCT 538 539	.
# #131	AnnotatorNotes T134	lemma = '.'
# T135	ADV 540 551	Furthermore
# #132	AnnotatorNotes T135	lemma = 'furthermore'
# T136	PUNCT 551 552	,
# #133	AnnotatorNotes T136	lemma = ','
# T137	DET 553 556	the
# #134	AnnotatorNotes T137	lemma = 'the'
# T138	VERB 557 564	copying
# #135	AnnotatorNotes T138	lemma = 'copy'
# T139	CCONJ 565 568	and
# #136	AnnotatorNotes T139	lemma = 'and'
# T140	VERB 569 576	sharing
# #137	AnnotatorNotes T140	lemma = 'shar'
# T141	NOUN 577 582	music
# #138	AnnotatorNotes T141	lemma = 'music'
# T142	CCONJ 583 585	or
# #139	AnnotatorNotes T142	lemma = 'or'
# T143	NOUN 586 591	films
# #140	AnnotatorNotes T143	lemma = 'film'
# T144	ADP 592 594	in
# #141	AnnotatorNotes T144	lemma = 'in'
# T145	ADP 595 597	of
# #142	AnnotatorNotes T145	lemma = 'of'
# T146	ADV 598 601	non
# #143	AnnotatorNotes T146	lemma = 'non'
# T147	PUNCT 601 602	-
# #144	AnnotatorNotes T147	lemma = '-'
# T148	ADJ 602 610	original
# #145	AnnotatorNotes T148	lemma = 'original'
# T149	NOUN 611 615	form
# #146	AnnotatorNotes T149	lemma = 'form'
# T150	NOUN 616 620	lead
# #147	AnnotatorNotes T150	lemma = 'lead'
# T151	ADP 621 623	to
# #148	AnnotatorNotes T151	lemma = 'to'
# T152	NOUN 624 637	deteriorating
# #149	AnnotatorNotes T152	lemma = 'deteriorate'
# T153	ADP 638 640	of
# #150	AnnotatorNotes T153	lemma = 'of'
# T154	DET 641 644	the
# #151	AnnotatorNotes T154	lemma = 'the'
# T155	NOUN 645 653	products
# #152	AnnotatorNotes T155	lemma = 'product'
# T156	ADP 653 654	’
# #153	AnnotatorNotes T156	lemma = '''
# T157	NOUN 655 662	quality
# #154	AnnotatorNotes T157	lemma = 'quality'
# T158	PUNCT 662 663	.
# #155	AnnotatorNotes T158	lemma = '.'
# T159	DET 664 667	The
# #156	AnnotatorNotes T159	lemma = 'the'
# T160	NOUN 668 674	reason
# #157	AnnotatorNotes T160	lemma = 'reason'
# T161	ADP 675 677	of
# #158	AnnotatorNotes T161	lemma = 'of'
# T162	PRON 678 680	it
# #159	AnnotatorNotes T162	lemma = 'it'
# T163	AUX 681 684	can
# #160	AnnotatorNotes T163	lemma = 'can'
# T164	AUX 685 687	be
# #161	AnnotatorNotes T164	lemma = 'be'
# T165	ADV 688 693	films
# #162	AnnotatorNotes T165	lemma = 'film'
# T166	VERB 694 702	recorded
# #163	AnnotatorNotes T166	lemma = 'record'
# T167	ADP 703 705	on
# #164	AnnotatorNotes T167	lemma = 'on'
# T168	NOUN 706 718	videocameras
# #165	AnnotatorNotes T168	lemma = 'videocamera'
# T169	ADP 719 723	from
# #166	AnnotatorNotes T169	lemma = 'from'
# T170	NOUN 724 735	cinemaparks
# #167	AnnotatorNotes T170	lemma = 'cinemapark'
# T171	CCONJ 736 738	or
# #168	AnnotatorNotes T171	lemma = 'or'
# T172	NOUN 739 744	music
# #169	AnnotatorNotes T172	lemma = 'music'
# T173	PUNCT 744 745	,
# #170	AnnotatorNotes T173	lemma = ','
# T174	ADJ 746 754	recorded
# #171	AnnotatorNotes T174	lemma = 'record'
# T175	ADP 755 757	on
# #172	AnnotatorNotes T175	lemma = 'on'
# T176	DET 758 761	the
# #173	AnnotatorNotes T176	lemma = 'the'
# T177	NOUN 762 770	concerts
# #174	AnnotatorNotes T177	lemma = 'concert'
# T178	PUNCT 770 771	.
# #175	AnnotatorNotes T178	lemma = '.'
# T179	ADP 772 774	In
# #176	AnnotatorNotes T179	lemma = 'in'
# T180	DET 775 779	such
# #177	AnnotatorNotes T180	lemma = 'such'
# T181	NOUN 780 783	way
# #178	AnnotatorNotes T181	lemma = 'way'
# T182	PRON 784 786	it
# #179	AnnotatorNotes T182	lemma = 'it'
# T183	VERB 787 792	seems
# #180	AnnotatorNotes T183	lemma = 'seem'
# T184	SCONJ 793 797	that
# #181	AnnotatorNotes T184	lemma = 'that'
# T185	NOUN 798 804	people
# #182	AnnotatorNotes T185	lemma = 'people'
# T186	ADP 805 807	of
# #183	AnnotatorNotes T186	lemma = 'of'
# T187	NOUN 808 811	art
# #184	AnnotatorNotes T187	lemma = 'art'
# T188	VERB 812 821	producing
# #185	AnnotatorNotes T188	lemma = 'producing'
# T189	ADV 822 828	really
# #186	AnnotatorNotes T189	lemma = 'really'
# T190	VERB 829 834	waste
# #187	AnnotatorNotes T190	lemma = 'waste'
# T191	DET 835 840	their
# #188	AnnotatorNotes T191	lemma = 'their'
# T192	NOUN 841 846	money
# #189	AnnotatorNotes T192	lemma = 'money'
# T193	PART 847 849	to
# #190	AnnotatorNotes T193	lemma = 'to'
# T194	VERB 850 856	create
# #191	AnnotatorNotes T194	lemma = 'create'
# T195	DET 857 858	a
# #192	AnnotatorNotes T195	lemma = 'a'
# T196	ADJ 859 863	good
# #193	AnnotatorNotes T196	lemma = 'good'
# T197	ADJ 864 876	proffesional
# #194	AnnotatorNotes T197	lemma = 'proffesional'
# T198	NOUN 877 884	picture
# #195	AnnotatorNotes T198	lemma = 'picture'
# T199	CCONJ 885 887	or
# #196	AnnotatorNotes T199	lemma = 'or'
# T200	NOUN 888 893	sound
# #197	AnnotatorNotes T200	lemma = 'sound'
# T201	PUNCT 893 894	.
# #198	AnnotatorNotes T201	lemma = '.'
# T202	ADP 895 897	On
# #199	AnnotatorNotes T202	lemma = 'on'
# T203	DET 898 901	the
# #200	AnnotatorNotes T203	lemma = 'the'
# T204	ADJ 902 907	other
# #201	AnnotatorNotes T204	lemma = 'other'
# T205	NOUN 908 912	hand
# #202	AnnotatorNotes T205	lemma = 'hand'
# T206	PUNCT 912 913	,
# #203	AnnotatorNotes T206	lemma = ','
# T207	ADP 914 916	in
# #204	AnnotatorNotes T207	lemma = 'in'
# T208	DET 917 920	the
# #205	AnnotatorNotes T208	lemma = 'the'
# T209	NOUN 921 924	era
# #206	AnnotatorNotes T209	lemma = 'era'
# T210	ADP 925 927	of
# #207	AnnotatorNotes T210	lemma = 'of'
# T211	VERB 928 938	developing
# #208	AnnotatorNotes T211	lemma = 'develop'
# T212	NOUN 939 951	technologies
# #209	AnnotatorNotes T212	lemma = 'technology'
# T213	PRON 952 954	it
# #210	AnnotatorNotes T213	lemma = 'it'
# T214	AUX 955 957	is
# #211	AnnotatorNotes T214	lemma = 'be'
# T215	ADV 958 964	really
# #212	AnnotatorNotes T215	lemma = 'really'
# T216	VERB 965 975	convenient
# #213	AnnotatorNotes T216	lemma = 'convenient'
# T217	PART 976 978	to
# #214	AnnotatorNotes T217	lemma = 'to'
# T218	VERB 979 982	use
# #215	AnnotatorNotes T218	lemma = 'use'
# T219	ADJ 983 989	social
# #216	AnnotatorNotes T219	lemma = 'social'
# T220	NOUN 990 998	networks
# #217	AnnotatorNotes T220	lemma = 'network'
# T221	CCONJ 999 1001	or
# #218	AnnotatorNotes T221	lemma = 'or'
# T222	ADJ 1002 1013	specialized
# #219	AnnotatorNotes T222	lemma = 'specialized'
# T223	NOUN 1014 1021	applies
# #220	AnnotatorNotes T223	lemma = 'apply'
# T224	ADP 1022 1024	as
# #221	AnnotatorNotes T224	lemma = 'as'
# T225	DET 1025 1026	a
# #222	AnnotatorNotes T225	lemma = 'a'
# T226	NOUN 1027 1035	platform
# #223	AnnotatorNotes T226	lemma = 'platform'
# T227	PART 1036 1038	to
# #224	AnnotatorNotes T227	lemma = 'to'
# T228	VERB 1039 1044	store
# #225	AnnotatorNotes T228	lemma = 'store'
# T229	ADJ 1045 1050	music
# #226	AnnotatorNotes T229	lemma = 'music'
# T230	NOUN 1051 1063	compositions
# #227	AnnotatorNotes T230	lemma = 'composition'
# T231	CCONJ 1064 1066	or
# #228	AnnotatorNotes T231	lemma = 'or'
# T232	NOUN 1067 1072	films
# #229	AnnotatorNotes T232	lemma = 'film'
# T233	PUNCT 1072 1073	.
# #230	AnnotatorNotes T233	lemma = '.'
# T234	ADV 1074 1078	Thus
# #231	AnnotatorNotes T234	lemma = 'thus'
# T235	PUNCT 1078 1079	,
# #232	AnnotatorNotes T235	lemma = ','
# T236	ADJ 1080 1084	many
# #233	AnnotatorNotes T236	lemma = 'many'
# T237	NOUN 1085 1091	people
# #234	AnnotatorNotes T237	lemma = 'people'
# T238	AUX 1092 1095	are
# #235	AnnotatorNotes T238	lemma = 'be'
# T239	ADJ 1096 1101	ready
# #236	AnnotatorNotes T239	lemma = 'ready'
# T240	PART 1102 1104	to
# #237	AnnotatorNotes T240	lemma = 'to'
# T241	VERB 1105 1111	commit
# #238	AnnotatorNotes T241	lemma = 'commit'
# T242	DET 1112 1113	a
# #239	AnnotatorNotes T242	lemma = 'a'
# T243	NOUN 1114 1117	law
# #240	AnnotatorNotes T243	lemma = 'law'
# T244	CCONJ 1118 1121	and
# #241	AnnotatorNotes T244	lemma = 'and'
# T245	VERB 1122 1126	have
# #242	AnnotatorNotes T245	lemma = 'have'
# T246	DET 1127 1128	a
# #243	AnnotatorNotes T246	lemma = 'a'
# T247	ADJ 1129 1133	free
# #244	AnnotatorNotes T247	lemma = 'free'
# T248	NOUN 1134 1140	wealth
# #245	AnnotatorNotes T248	lemma = 'wealth'
# T249	PUNCT 1140 1141	.
# #246	AnnotatorNotes T249	lemma = '.'
# T250	ADV 1142 1149	However
# #247	AnnotatorNotes T250	lemma = 'however'
# T251	PUNCT 1149 1150	,
# #248	AnnotatorNotes T251	lemma = ','
# T252	DET 1151 1155	this
# #249	AnnotatorNotes T252	lemma = 'this'
# T253	NOUN 1156 1163	problem
# #250	AnnotatorNotes T253	lemma = 'problem'
# T254	AUX 1164 1166	is
# #251	AnnotatorNotes T254	lemma = 'be'
# T255	VERB 1167 1174	decided
# #252	AnnotatorNotes T255	lemma = 'decid'
# T256	ADP 1175 1177	by
# #253	AnnotatorNotes T256	lemma = 'by'
# T257	ADJ 1178 1183	Apple
# #254	AnnotatorNotes T257	lemma = 'Apple'
# T258	NOUN 1184 1195	corporation
# #255	AnnotatorNotes T258	lemma = 'corporation'
# T259	PRON 1196 1201	which
# #256	AnnotatorNotes T259	lemma = 'which'
# T260	AUX 1202 1205	has
# #257	AnnotatorNotes T260	lemma = 'have'
# T261	DET 1206 1207	a
# #258	AnnotatorNotes T261	lemma = 'a'
# T262	ADJ 1208 1212	huge
# #259	AnnotatorNotes T262	lemma = 'huge'
# T263	NOUN 1213 1218	music
# #260	AnnotatorNotes T263	lemma = 'music'
# T264	NOUN 1219 1227	resource
# #261	AnnotatorNotes T264	lemma = 'resource'
# T265	ADJ 1228 1232	free
# #262	AnnotatorNotes T265	lemma = 'free'
# T266	ADP 1233 1236	for
# #263	AnnotatorNotes T266	lemma = 'for'
# T267	NUM 1237 1242	three
# #264	AnnotatorNotes T267	lemma = 'three'
# T268	NOUN 1243 1249	months
# #265	AnnotatorNotes T268	lemma = 'month'
# T269	PUNCT 1249 1250	.
# #266	AnnotatorNotes T269	lemma = '.'
# T270	ADV 1251 1259	Moreover
# #267	AnnotatorNotes T270	lemma = 'moreover'
# T271	PUNCT 1259 1260	,
# #268	AnnotatorNotes T271	lemma = ','
# T272	ADV 1261 1266	there
# #269	AnnotatorNotes T272	lemma = 'there'
# T273	VERB 1267 1269	is
# #270	AnnotatorNotes T273	lemma = 'be'
# T274	DET 1270 1271	a
# #271	AnnotatorNotes T274	lemma = 'a'
# T275	NOUN 1272 1279	problem
# #272	AnnotatorNotes T275	lemma = 'problem'
# T276	ADP 1280 1282	of
# #273	AnnotatorNotes T276	lemma = 'of'
# T277	NOUN 1283 1289	people
# #274	AnnotatorNotes T277	lemma = 'people'
# T278	ADP 1289 1291	’s
# #275	AnnotatorNotes T278	lemma = '’s'
# T279	NOUN 1292 1300	equality
# #276	AnnotatorNotes T279	lemma = 'equality'
# T280	PUNCT 1300 1301	.
# #277	AnnotatorNotes T280	lemma = '.'
# T281	PRON 1302 1304	It
# #278	AnnotatorNotes T281	lemma = 'it'
# T282	AUX 1305 1307	is
# #279	AnnotatorNotes T282	lemma = 'be'
# T283	VERB 1308 1318	considered
# #280	AnnotatorNotes T283	lemma = 'consider'
# T284	SCONJ 1319 1323	that
# #281	AnnotatorNotes T284	lemma = 'that'
# T285	PRON 1324 1332	everyone
# #282	AnnotatorNotes T285	lemma = 'everyone'
# T286	AUX 1333 1339	should
# #283	AnnotatorNotes T286	lemma = 'shall'
# T287	VERB 1340 1344	have
# #284	AnnotatorNotes T287	lemma = 'have'
# T288	DET 1345 1346	a
# #285	AnnotatorNotes T288	lemma = 'a'
# T289	NOUN 1347 1352	right
# #286	AnnotatorNotes T289	lemma = 'right'
# T290	PART 1353 1355	to
# #287	AnnotatorNotes T290	lemma = 'to'
# T291	VERB 1356 1359	use
# #288	AnnotatorNotes T291	lemma = 'use'
# T292	DET 1360 1361	a
# #289	AnnotatorNotes T292	lemma = 'a'
# T293	NOUN 1362 1368	wealth
# #290	AnnotatorNotes T293	lemma = 'wealth'
# T294	PRON 1369 1374	which
# #291	AnnotatorNotes T294	lemma = 'which'
# T295	AUX 1375 1377	is
# #292	AnnotatorNotes T295	lemma = 'be'
# T296	VERB 1378 1382	made
# #293	AnnotatorNotes T296	lemma = 'make'
# T297	CCONJ 1383 1386	and
# #294	AnnotatorNotes T297	lemma = 'and'
# T298	VERB 1387 1395	prepared
# #295	AnnotatorNotes T298	lemma = 'prepare'
# T299	ADP 1396 1398	to
# #296	AnnotatorNotes T299	lemma = 'to'
# T300	ADJ 1399 1405	public
# #297	AnnotatorNotes T300	lemma = 'public'
# T301	PUNCT 1405 1406	.
# #298	AnnotatorNotes T301	lemma = '.'
# T302	ADV 1407 1409	So
# #299	AnnotatorNotes T302	lemma = 'so'
# T303	PUNCT 1409 1410	,
# #300	AnnotatorNotes T303	lemma = ','
# T304	PRON 1411 1413	it
# #301	AnnotatorNotes T304	lemma = 'it'
# T305	AUX 1414 1420	should
# #302	AnnotatorNotes T305	lemma = 'shall'
# T306	AUX 1421 1423	be
# #303	AnnotatorNotes T306	lemma = 'be'
# T307	ADJ 1424 1433	available
# #304	AnnotatorNotes T307	lemma = 'available'
# T308	PART 1434 1437	not
# #305	AnnotatorNotes T308	lemma = 'not'
# T309	ADV 1438 1442	only
# #306	AnnotatorNotes T309	lemma = 'only'
# T310	ADP 1443 1446	for
# #307	AnnotatorNotes T310	lemma = 'for'
# T311	DET 1447 1452	those
# #308	AnnotatorNotes T311	lemma = 'that'
# T312	NOUN 1453 1459	people
# #309	AnnotatorNotes T312	lemma = 'people'
# T313	PRON 1460 1463	who
# #310	AnnotatorNotes T313	lemma = 'who'
# T314	VERB 1464 1468	have
# #311	AnnotatorNotes T314	lemma = 'have'
# T315	DET 1469 1470	a
# #312	AnnotatorNotes T315	lemma = 'a'
# T316	ADJ 1471 1480	financial
# #313	AnnotatorNotes T316	lemma = 'financial'
# T317	NOUN 1481 1492	opportunity
# #314	AnnotatorNotes T317	lemma = 'opportunity'
# T318	PART 1493 1495	to
# #315	AnnotatorNotes T318	lemma = 'to'
# T319	VERB 1496 1499	pay
# #316	AnnotatorNotes T319	lemma = 'pay'
# T320	ADP 1500 1503	for
# #317	AnnotatorNotes T320	lemma = 'for'
# T321	NOUN 1504 1513	listening
# #318	AnnotatorNotes T321	lemma = 'listening'
# T322	ADP 1514 1517	for
# #319	AnnotatorNotes T322	lemma = 'for'
# T323	DET 1518 1519	a
# #320	AnnotatorNotes T323	lemma = 'a'
# T324	NOUN 1520 1525	music
# #321	AnnotatorNotes T324	lemma = 'music'
# T325	CCONJ 1526 1528	or
# #322	AnnotatorNotes T325	lemma = 'or'
# T326	NOUN 1529 1537	watching
# #323	AnnotatorNotes T326	lemma = 'watch'
# T327	NOUN 1538 1543	films
# #324	AnnotatorNotes T327	lemma = 'film'
# T328	PUNCT 1543 1544	.
# #325	AnnotatorNotes T328	lemma = '.'
# T329	ADP 1545 1547	To
# #326	AnnotatorNotes T329	lemma = 'to'
# T330	VERB 1548 1551	sum
# #327	AnnotatorNotes T330	lemma = 'sum'
# T331	ADV 1552 1554	up
# #328	AnnotatorNotes T331	lemma = 'up'
# T332	PUNCT 1554 1555	,
# #329	AnnotatorNotes T332	lemma = ','
# T333	PRON 1556 1558	it
# #330	AnnotatorNotes T333	lemma = 'it'
# T334	AUX 1559 1561	is
# #331	AnnotatorNotes T334	lemma = 'be'
# T335	ADV 1562 1568	really
# #332	AnnotatorNotes T335	lemma = 'really'
# T336	ADJ 1569 1578	important
# #333	AnnotatorNotes T336	lemma = 'important'
# T337	ADP 1579 1582	for
# #334	AnnotatorNotes T337	lemma = 'for'
# T338	NOUN 1583 1592	musicians
# #335	AnnotatorNotes T338	lemma = 'musician'
# T339	CCONJ 1593 1596	and
# #336	AnnotatorNotes T339	lemma = 'and'
# T340	NOUN 1597 1601	film
# #337	AnnotatorNotes T340	lemma = 'film'
# T341	NOUN 1602 1611	producers
# #338	AnnotatorNotes T341	lemma = 'producer'
# T342	PART 1612 1614	to
# #339	AnnotatorNotes T342	lemma = 'to'
# T343	VERB 1615 1620	share
# #340	AnnotatorNotes T343	lemma = 'share'
# T344	DET 1621 1626	their
# #341	AnnotatorNotes T344	lemma = 'their'
# T345	NOUN 1627 1640	“masterpieces
# #342	AnnotatorNotes T345	lemma = '“masterpiece'
# T346	PUNCT 1640 1641	”
# #343	AnnotatorNotes T346	lemma = '”'
# T347	ADP 1642 1646	with
# #344	AnnotatorNotes T347	lemma = 'with'
# T348	DET 1647 1650	all
# #345	AnnotatorNotes T348	lemma = 'all'
# T349	NOUN 1651 1657	people
# #346	AnnotatorNotes T349	lemma = 'people'
# T350	ADP 1658 1660	in
# #347	AnnotatorNotes T350	lemma = 'in'
# T351	ADJ 1661 1666	equal
# #348	AnnotatorNotes T351	lemma = 'equal'
# T352	NOUN 1667 1671	form
# #349	AnnotatorNotes T352	lemma = 'form'
# T353	PUNCT 1671 1672	.
# #350	AnnotatorNotes T353	lemma = '.'
