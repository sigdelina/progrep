# %%
import re
import os

with open('sentences.csv', 'w', encoding='utf-8') as file: 
    row = '%s\t%s\t%s\t%s\t%s\t%s\t%s\n'
    file.write(row % ('Path', 'Tag', 'Full sentence', 'Tagged mistake', 
                   'Corrected mistake', 'Correct/incorrect', 'Group'))
path = './data/exam2017_1'
for root, dirs, files in os.walk(path):
    for file in files:
        if ".ann" in file:
            print(root, dirs, file)
            final = os.path.join(root, file)
            with open(final, encoding="utf-8") as file:
                annot_txt = file.read()
          #  print(annot_txt)
            clean_text = annot_txt.splitlines()
           # print(clean_text)
            for line in clean_text:
              #  print(line)
                find_tag = re.search(r'T.*?Tense_choice.*?\D', line)
                if find_tag is not None:
                    reg_mistake = re.search(r'\s\d*?\s\d*?\s(\D+)', line, flags=re.DOTALL)
                    tag_mistake = reg_mistake.group(1)
                    print(tag_mistake)
                    reg_correct = re.search(r'T.*?Tense_choice.*?\D.*\n#.*T\d*?\s(\D+)', line, flags=re.DOTALL)
                    if reg_correct is None:
                        correct_mistake = ' - '
                    else:
                        correct_mistake = reg_correct.group(0)
                    print(correct_mistake)
                    with open('final.csv', 'a', encoding='utf-8') as f:
                        row = '%s\tTense_choice\t%s\t%s\t%s\n'
                        f.write(row % (final, 'gt', tag_mistake, correct_mistake))
# Out:
# ./data/exam2017_1 [] ABl_9_1.ann
# is
#  -
# can not find
#  -
# ./data/exam2017_1 [] ABl_9_2.ann
# would not have
#  -
# are really developed
#  -
# ./data/exam2017_1 [] ABl_8_2.ann
# gained
#  -
# buying
#  -
# wouldn’t to buy
#  -
# can’t
#  -
# know
#  -
# to losing
#  -
# ./data/exam2017_1 []  DOv_29_2.ann
# ./data/exam2017_1 [] ABl_8_1.ann
# remain
#  -
# is
#  -
# indicate
#  -
# rest
#  -
# is
#  -
# is
#  -
# have
#  -
# presented
#  -
# ./data/exam2017_1 [] ABl_6_2.ann
# increasing
#  -
# has become
#  -
# ./data/exam2017_1 [] ABl_10_1.ann
# ./data/exam2017_1 [] ABl_12_2.ann
# appeared
#  -
# ./data/exam2017_1 [] ABl_4_1.ann
# shows
#  -
# illustrate
#  -
# shows
#  -
# is
#  -
# is
#  -
# ./data/exam2017_1 [] ABl_6_1.ann
# was becoming
#  -
# ./data/exam2017_1 [] ABl_10_2.ann
# ./data/exam2017_1 [] ABl_12_1.ann
# is
#  -
# remain
#  -
# is erratic
#  -
# is
#  -
# has
#  -
# is
#  -
# had changed
#  -
# ./data/exam2017_1 [] ABl_4_2.ann
# ./data/exam2017_1 [] ABl_16_1.ann
# ./data/exam2017_1 [] ABl_2_1.ann
# is
#  -
# is
#  -
# ./data/exam2017_1 [] ABl_14_2.ann
# spent
#  -
# made
#  -
# sent
#  -
# could
#  -
# said
#  -
# ./data/exam2017_1 [] ABl_16_2.ann
# will not know
#  -
# ./data/exam2017_1 [] ABl_2_2.ann
# ./data/exam2017_1 [] ABl_14_1.ann
# shows
#  -
# is
#  -
# is
#  -
# is
#  -
# shows
#  -
# demonstrate
#  -
# do not changing
#  -
# do not changes
#  -
# ./data/exam2017_1 [] ABl_11_2.ann
# use
#  -
# were
#  -
# ./data/exam2017_1 [] ABl_7_1.ann
# has shown
#  -
# is
#  -
# is
#  -
# is
#  -
# remains
#  -
# is
#  -
# is
#  -
# remain
#  -
# ./data/exam2017_1 [] ABl_5_2.ann
# ./data/exam2017_1 [] ABl_13_1.ann
# has changed
#  -
# has changed
#  -
# is
#  -
# is
#  -
# are
#  -
# are
#  -
# can
#  -
# ./data/exam2017_1 [] ABl_11_1.ann
# ./data/exam2017_1 [] ABl_7_2.ann
# could not
#  -
# ./data/exam2017_1 [] ABl_5_1.ann
# talking
#  -
# ./data/exam2017_1 [] ABl_13_2.ann
# get
#  -
# ./data/exam2017_1 [] ABl_1_1.ann
# may be stimulated
#  -
# is
#  -
# is
#  -
# is
#  -
# remains
#  -
# is
#  -
# is
#  -
# ./data/exam2017_1 [] ABl_15_1.ann
# is
#  -
# has
#  -
# are
#  -
# is
#  -
# is
#  -
# have
#  -
# has
#  -
# have
#  -
# are
#  -
# ./data/exam2017_1 [] ABl_3_2.ann
# will juge
#  -
# ./data/exam2017_1 [] ABL_1_2.ann
# spent
#  -
# like
#  -
# ./data/exam2017_1 [] ABl_15_2.ann
# ./data/exam2017_1 [] ABl_3_1.ann
# are
#  -
# are
#  -
# are falling down or stay
#  -
# stay
#  -
